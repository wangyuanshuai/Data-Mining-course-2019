# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
winedata = pd.read_csv(open("winemag-data-130k-v2.csv",encoding='utf-8'))# 读取数据集
winedata = winedata.dropna()
winedata.head()
# Out:
#     Unnamed: 0 country                                        description  \
# 4            4      US  Much like the regular bottling from 2012, this...
# 10          10      US  Soft, supple plum envelopes an oaky structure ...
# 23          23      US  This wine from the Geneseo district offers aro...
# 25          25      US  Oak and earth intermingle around robust aromas...
# 35          35      US  As with many of the Erath 2010 vineyard design...
#
#                            designation  points  price    province  \
# 4   Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 10                      Mountain Cuvée      87   19.0  California
# 23                 Signature Selection      87   22.0  California
# 25                 King Ridge Vineyard      87   69.0  California
# 35                              Hyland      86   50.0      Oregon
#
#              region_1           region_2     taster_name  \
# 4   Willamette Valley  Willamette Valley    Paul Gregutt
# 10        Napa Valley               Napa  Virginie Boone
# 23        Paso Robles      Central Coast   Matt Kettmann
# 25       Sonoma Coast             Sonoma  Virginie Boone
# 35        McMinnville  Willamette Valley    Paul Gregutt
#
#    taster_twitter_handle                                              title  \
# 4            @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 10               @vboone  Kirkland Signature 2011 Mountain Cuvée Caberne...
# 23         @mattkettmann  Bianchi 2011 Signature Selection Merlot (Paso ...
# 25               @vboone  Castello di Amorosa 2011 King Ridge Vineyard P...
# 35           @paulgwine          Erath 2010 Hyland Pinot Noir (McMinnville)
#
#                variety               winery
# 4           Pinot Noir         Sweet Cheeks
# 10  Cabernet Sauvignon   Kirkland Signature
# 23              Merlot              Bianchi
# 25          Pinot Noir  Castello di Amorosa
# 35          Pinot Noir                Erath

# %%
winedata = winedata.copy().drop(columns=['Unnamed: 0','description'])# 删除Unnamed: 0和description
winedata.info()
np.array(winedata.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22387 entries, 4 to 129950
# Data columns (total 12 columns):
# country                  22387 non-null object
# designation              22387 non-null object
# points                   22387 non-null int64
# price                    22387 non-null float64
# province                 22387 non-null object
# region_1                 22387 non-null object
# region_2                 22387 non-null object
# taster_name              22387 non-null object
# taster_twitter_handle    22387 non-null object
# title                    22387 non-null object
# variety                  22387 non-null object
# winery                   22387 non-null object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 2.2+ MB
# array([['US', "Vintner's Reserve Wild Child Block", 87, 65.0, 'Oregon',
#         'Willamette Valley', 'Willamette Valley', 'Paul Gregutt',
#         '@paulgwine\xa0',
#         "Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)",
#         'Pinot Noir', 'Sweet Cheeks'],
#        ['US', 'Mountain Cuvée', 87, 19.0, 'California', 'Napa Valley',
#         'Napa', 'Virginie Boone', '@vboone',
#         'Kirkland Signature 2011 Mountain Cuvée Cabernet Sauvignon (Napa Valley)',
#         'Cabernet Sauvignon', 'Kirkland Signature'],
#        ['US', 'Signature Selection', 87, 22.0, 'California',
#         'Paso Robles', 'Central Coast', 'Matt Kettmann', '@mattkettmann',
#         'Bianchi 2011 Signature Selection Merlot (Paso Robles)',
#         'Merlot', 'Bianchi'],
#        ['US', 'King Ridge Vineyard', 87, 69.0, 'California',
#         'Sonoma Coast', 'Sonoma', 'Virginie Boone', '@vboone',
#         'Castello di Amorosa 2011 King Ridge Vineyard Pinot Noir (Sonoma Coast)',
#         'Pinot Noir', 'Castello di Amorosa'],
#        ['US', 'Hyland', 86, 50.0, 'Oregon', 'McMinnville',
#         'Willamette Valley', 'Paul Gregutt', '@paulgwine\xa0',
#         'Erath 2010 Hyland Pinot Noir (McMinnville)', 'Pinot Noir',
#         'Erath']], dtype=object)

# %%
# 处理points
bin = [0,75,80,85,90,95,100]
winedata['points'] = pd.cut(winedata['points'],bin)
winedata['points'] = winedata['points'].astype('str')
# 处理price
bin = [0,20,30,40,50,60,2100]
winedata['price'] = pd.cut(winedata['price'],bin)
winedata['price'] = winedata['price'].astype('str')

# %%
def createC1( dataSet ):
    C1 = []
    for transaction in np.array(dataSet):# 构建初始候选项集的列表，即所有候选项集只包含一个元素，C1是大小为1的所有候选项集的集合
        for item in transaction:
            if [item] not in C1:
                C1.append( [item] )
    C1.sort()
    return list(map( frozenset, C1 ))

def scanD( D, Ck, minSupport ):
  
    ssCnt = {}   
    for tid in D:
        if Ck is not None:   # 对于每一条transaction
            for can in Ck:
                if can.issubset( tid ):
                    ssCnt[ can ] = ssCnt.get( can, 0) + 1
    numItems = float( len( D ) )
    retList = []
    supportData = {}
    for key in ssCnt:  
        support = ssCnt[ key ] / numItems# 每个项集的支持度  
        if support >= minSupport:
            retList.insert( 0, key ) # 将满足最小支持度的项集，加入retList
            supportData[ key ] = support
    return retList, supportData

# %%
# Aprior算法
def aprioriGen( Lk, k ):
    retList = []
    lenLk = len( Lk )
    for i in range( lenLk ):
        for j in range( i + 1, lenLk ):
            L1 = list( Lk[ i ] )[ : k - 2 ];
            L2 = list( Lk[ j ] )[ : k - 2 ];
            L1.sort();L2.sort()    
            if L1==L2:
                retList.append( Lk[ i ] | Lk[ j ] ) 
    return retList

def apriori( dataSet, minSupport = 0.5 ):
 
    C1 = createC1( dataSet )   # 构建初始候选项集C1
    D =list( map( set, dataSet )) # 将dataSet集合化
    L1, suppData = scanD( D, C1, minSupport )    # 构建初始的频繁项集，即所有项集只有一个元素
    L = [ L1 ]
    k = 2
    while ( len( L[ k - 2 ] ) > 0 ):
        Ck = aprioriGen( L[ k - 2 ], k )
        Lk, supK = scanD( D, Ck, minSupport )
        suppData.update( supK )
        L.append( Lk )
        k += 1
    return L, suppData
myDat = list(map(set,np.array(winedata)))
L, suppData = apriori(myDat, 0.05)
L #输出结果
# Out:
# [[frozenset({'(80, 85]'}),
#   frozenset({'Chardonnay'}),
#   frozenset({'Jim Gordon'}),
#   frozenset({'@gordone_cellars'}),
#   frozenset({'Russian River Valley'}),
#   frozenset({'Syrah'}),
#   frozenset({'(90, 95]'}),
#   frozenset({'Red Blend'}),
#   frozenset({'(50, 60]'}),
#   frozenset({'(30, 40]'}),
#   frozenset({'Washington'}),
#   frozenset({'Sean P. Sullivan'}),
#   frozenset({'Columbia Valley (WA)'}),
#   frozenset({'Columbia Valley'}),
#   frozenset({'@wawinereport'}),
#   frozenset({'(40, 50]'}),
#   frozenset({'Sonoma'}),
#   frozenset({'Matt Kettmann'}),
#   frozenset({'Central Coast'}),
#   frozenset({'@mattkettmann'}),
#   frozenset({'(20, 30]'}),
#   frozenset({'Virginie Boone'}),
#   frozenset({'Napa Valley'}),
#   frozenset({'Napa'}),
#   frozenset({'California'}),
#   frozenset({'Cabernet Sauvignon'}),
#   frozenset({'@vboone'}),
#   frozenset({'(0, 20]'}),
#   frozenset({'Willamette Valley'}),
#   frozenset({'US'}),
#   frozenset({'Pinot Noir'}),
#   frozenset({'Paul Gregutt'}),
#   frozenset({'Oregon'}),
#   frozenset({'@paulgwine\xa0'}),
#   frozenset({'(85, 90]'}),
#   frozenset({'(60, 2100]'})],
#  [frozenset({'(30, 40]', 'Columbia Valley'}),
#   frozenset({'(30, 40]', 'Washington'}),
#   frozenset({'(90, 95]', 'Columbia Valley'}),
#   frozenset({'(90, 95]', 'Washington'}),
#   frozenset({'(0, 20]', '@paulgwine\xa0'}),
#   frozenset({'(0, 20]', 'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Paul Gregutt'}),
#   frozenset({'(0, 20]', 'Columbia Valley'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)'}),
#   frozenset({'Columbia Valley (WA)', 'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Washington'}),
#   frozenset({'Paul Gregutt', 'Washington'}),
#   frozenset({'(0, 20]', 'Washington'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0'}),
#   frozenset({'(90, 95]', 'Oregon'}),
#   frozenset({'(90, 95]', 'Paul Gregutt'}),
#   frozenset({'(30, 40]', '@paulgwine\xa0'}),
#   frozenset({'(30, 40]', 'Paul Gregutt'}),
#   frozenset({'(80, 85]', 'US'}),
#   frozenset({'(85, 90]', 'Chardonnay'}),
#   frozenset({'Chardonnay', 'US'}),
#   frozenset({'California', 'Chardonnay'}),
#   frozenset({'(85, 90]', '@gordone_cellars'}),
#   frozenset({'@gordone_cellars', 'US'}),
#   frozenset({'@gordone_cellars', 'California'}),
#   frozenset({'(85, 90]', 'Jim Gordon'}),
#   frozenset({'Jim Gordon', 'US'}),
#   frozenset({'California', 'Jim Gordon'}),
#   frozenset({'@gordone_cellars', 'Jim Gordon'}),
#   frozenset({'(40, 50]', '@vboone'}),
#   frozenset({'(40, 50]', 'Virginie Boone'}),
#   frozenset({'(90, 95]', 'Sonoma'}),
#   frozenset({'Russian River Valley', 'US'}),
#   frozenset({'@vboone', 'Russian River Valley'}),
#   frozenset({'California', 'Russian River Valley'}),
#   frozenset({'Russian River Valley', 'Virginie Boone'}),
#   frozenset({'Russian River Valley', 'Sonoma'}),
#   frozenset({'(40, 50]', 'California'}),
#   frozenset({'(40, 50]', '(90, 95]'}),
#   frozenset({'Syrah', 'US'}),
#   frozenset({'(50, 60]', '(90, 95]'}),
#   frozenset({'(20, 30]', '(90, 95]'}),
#   frozenset({'(30, 40]', '(90, 95]'}),
#   frozenset({'@mattkettmann', 'Pinot Noir'}),
#   frozenset({'Central Coast', 'Pinot Noir'}),
#   frozenset({'Matt Kettmann', 'Pinot Noir'}),
#   frozenset({'(90, 95]', 'Pinot Noir'}),
#   frozenset({'(90, 95]', '@mattkettmann'}),
#   frozenset({'(90, 95]', 'Central Coast'}),
#   frozenset({'(90, 95]', 'Matt Kettmann'}),
#   frozenset({'(60, 2100]', '(90, 95]'}),
#   frozenset({'(90, 95]', 'US'}),
#   frozenset({'(90, 95]', '@vboone'}),
#   frozenset({'(90, 95]', 'California'}),
#   frozenset({'(90, 95]', 'Virginie Boone'}),
#   frozenset({'(85, 90]', 'Red Blend'}),
#   frozenset({'Red Blend', 'US'}),
#   frozenset({'(20, 30]', '@vboone'}),
#   frozenset({'(20, 30]', 'Virginie Boone'}),
#   frozenset({'(20, 30]', '@paulgwine\xa0'}),
#   frozenset({'(20, 30]', 'Paul Gregutt'}),
#   frozenset({'(50, 60]', 'US'}),
#   frozenset({'(50, 60]', 'California'}),
#   frozenset({'(30, 40]', '(85, 90]'}),
#   frozenset({'(30, 40]', 'US'}),
#   frozenset({'(30, 40]', '@vboone'}),
#   frozenset({'(30, 40]', 'California'}),
#   frozenset({'(30, 40]', 'Virginie Boone'}),
#   frozenset({'(85, 90]', '@wawinereport'}),
#   frozenset({'@wawinereport', 'US'}),
#   frozenset({'(85, 90]', 'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'US'}),
#   frozenset({'(20, 30]', 'Columbia Valley'}),
#   frozenset({'@wawinereport', 'Columbia Valley'}),
#   frozenset({'(85, 90]', 'Columbia Valley (WA)'}),
#   frozenset({'Columbia Valley (WA)', 'US'}),
#   frozenset({'@wawinereport', 'Columbia Valley (WA)'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)'}),
#   frozenset({'(85, 90]', 'Sean P. Sullivan'}),
#   frozenset({'Sean P. Sullivan', 'US'}),
#   frozenset({'@wawinereport', 'Sean P. Sullivan'}),
#   frozenset({'Columbia Valley', 'Sean P. Sullivan'}),
#   frozenset({'Columbia Valley (WA)', 'Sean P. Sullivan'}),
#   frozenset({'(85, 90]', 'Washington'}),
#   frozenset({'US', 'Washington'}),
#   frozenset({'(20, 30]', 'Washington'}),
#   frozenset({'@wawinereport', 'Washington'}),
#   frozenset({'Columbia Valley', 'Washington'}),
#   frozenset({'Columbia Valley (WA)', 'Washington'}),
#   frozenset({'Sean P. Sullivan', 'Washington'}),
#   frozenset({'(40, 50]', '(85, 90]'}),
#   frozenset({'(40, 50]', 'Pinot Noir'}),
#   frozenset({'(40, 50]', 'US'}),
#   frozenset({'(60, 2100]', '@vboone'}),
#   frozenset({'@vboone', 'Pinot Noir'}),
#   frozenset({'(60, 2100]', 'California'}),
#   frozenset({'California', 'Pinot Noir'}),
#   frozenset({'(60, 2100]', 'Virginie Boone'}),
#   frozenset({'Pinot Noir', 'Virginie Boone'}),
#   frozenset({'(85, 90]', 'Sonoma'}),
#   frozenset({'Pinot Noir', 'Sonoma'}),
#   frozenset({'Sonoma', 'US'}),
#   frozenset({'@vboone', 'Sonoma'}),
#   frozenset({'California', 'Sonoma'}),
#   frozenset({'Sonoma', 'Virginie Boone'}),
#   frozenset({'(20, 30]', '(85, 90]'}),
#   frozenset({'(20, 30]', 'US'}),
#   frozenset({'(20, 30]', 'California'}),
#   frozenset({'(85, 90]', '@mattkettmann'}),
#   frozenset({'@mattkettmann', 'US'}),
#   frozenset({'@mattkettmann', 'California'}),
#   frozenset({'(85, 90]', 'Central Coast'}),
#   frozenset({'Central Coast', 'US'}),
#   frozenset({'California', 'Central Coast'}),
#   frozenset({'@mattkettmann', 'Central Coast'}),
#   frozenset({'(85, 90]', 'Matt Kettmann'}),
#   frozenset({'Matt Kettmann', 'US'}),
#   frozenset({'California', 'Matt Kettmann'}),
#   frozenset({'@mattkettmann', 'Matt Kettmann'}),
#   frozenset({'Central Coast', 'Matt Kettmann'}),
#   frozenset({'(0, 20]', '(85, 90]'}),
#   frozenset({'(0, 20]', 'US'}),
#   frozenset({'(85, 90]', '@vboone'}),
#   frozenset({'@vboone', 'US'}),
#   frozenset({'(85, 90]', 'Cabernet Sauvignon'}),
#   frozenset({'Cabernet Sauvignon', 'US'}),
#   frozenset({'@vboone', 'Cabernet Sauvignon'}),
#   frozenset({'(85, 90]', 'California'}),
#   frozenset({'California', 'US'}),
#   frozenset({'(0, 20]', 'California'}),
#   frozenset({'@vboone', 'California'}),
#   frozenset({'Cabernet Sauvignon', 'California'}),
#   frozenset({'Napa', 'US'}),
#   frozenset({'@vboone', 'Napa'}),
#   frozenset({'California', 'Napa'}),
#   frozenset({'Napa Valley', 'US'}),
#   frozenset({'@vboone', 'Napa Valley'}),
#   frozenset({'California', 'Napa Valley'}),
#   frozenset({'Napa', 'Napa Valley'}),
#   frozenset({'(85, 90]', 'Virginie Boone'}),
#   frozenset({'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Virginie Boone'}),
#   frozenset({'Cabernet Sauvignon', 'Virginie Boone'}),
#   frozenset({'California', 'Virginie Boone'}),
#   frozenset({'Napa', 'Virginie Boone'}),
#   frozenset({'Napa Valley', 'Virginie Boone'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0'}),
#   frozenset({'(85, 90]', 'Oregon'}),
#   frozenset({'@paulgwine\xa0', 'Oregon'}),
#   frozenset({'(85, 90]', 'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt'}),
#   frozenset({'Oregon', 'Paul Gregutt'}),
#   frozenset({'(85, 90]', 'Pinot Noir'}),
#   frozenset({'@paulgwine\xa0', 'Pinot Noir'}),
#   frozenset({'Oregon', 'Pinot Noir'}),
#   frozenset({'Paul Gregutt', 'Pinot Noir'}),
#   frozenset({'(60, 2100]', 'US'}),
#   frozenset({'(85, 90]', 'US'}),
#   frozenset({'@paulgwine\xa0', 'US'}),
#   frozenset({'Oregon', 'US'}),
#   frozenset({'Paul Gregutt', 'US'}),
#   frozenset({'Pinot Noir', 'US'}),
#   frozenset({'(85, 90]', 'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0', 'Willamette Valley'}),
#   frozenset({'Oregon', 'Willamette Valley'}),
#   frozenset({'Paul Gregutt', 'Willamette Valley'}),
#   frozenset({'Pinot Noir', 'Willamette Valley'}),
#   frozenset({'US', 'Willamette Valley'})],
#  [frozenset({'(30, 40]', 'US', 'Washington'}),
#   frozenset({'(30, 40]', 'Columbia Valley', 'US'}),
#   frozenset({'(90, 95]', 'US', 'Washington'}),
#   frozenset({'(90, 95]', 'Columbia Valley', 'US'}),
#   frozenset({'(90, 95]', 'Columbia Valley', 'Washington'}),
#   frozenset({'(30, 40]', 'Columbia Valley', 'Washington'}),
#   frozenset({'(0, 20]', 'Paul Gregutt', 'US'}),
#   frozenset({'Paul Gregutt', 'US', 'Washington'}),
#   frozenset({'(0, 20]', 'US', 'Washington'}),
#   frozenset({'Columbia Valley (WA)', 'Paul Gregutt', 'US'}),
#   frozenset({'Columbia Valley', 'Paul Gregutt', 'US'}),
#   frozenset({'(0, 20]', 'Columbia Valley', 'US'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Paul Gregutt'}),
#   frozenset({'(0, 20]', 'Columbia Valley', 'Washington'}),
#   frozenset({'Columbia Valley (WA)', 'Paul Gregutt', 'Washington'}),
#   frozenset({'Columbia Valley', 'Paul Gregutt', 'Washington'}),
#   frozenset({'(85, 90]', 'Paul Gregutt', 'Washington'}),
#   frozenset({'@paulgwine\xa0', 'US', 'Washington'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Washington'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Washington'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'US'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'Washington'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'US'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Paul Gregutt'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Columbia Valley'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Washington'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Columbia Valley (WA)'}),
#   frozenset({'(0, 20]', '@paulgwine\xa0', 'US'}),
#   frozenset({'(0, 20]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   frozenset({'(90, 95]', 'Paul Gregutt', 'US'}),
#   frozenset({'(90, 95]', 'Oregon', 'US'}),
#   frozenset({'(90, 95]', 'Oregon', 'Paul Gregutt'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'US'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Oregon'}),
#   frozenset({'(30, 40]', 'Paul Gregutt', 'US'}),
#   frozenset({'(30, 40]', '@paulgwine\xa0', 'US'}),
#   frozenset({'(30, 40]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   frozenset({'(85, 90]', 'Chardonnay', 'US'}),
#   frozenset({'California', 'Chardonnay', 'US'}),
#   frozenset({'@gordone_cellars', 'California', 'Jim Gordon'}),
#   frozenset({'@gordone_cellars', 'Jim Gordon', 'US'}),
#   frozenset({'California', 'Jim Gordon', 'US'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'Jim Gordon'}),
#   frozenset({'(85, 90]', 'California', 'Jim Gordon'}),
#   frozenset({'(85, 90]', 'Jim Gordon', 'US'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'California'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'US'}),
#   frozenset({'@gordone_cellars', 'California', 'US'}),
#   frozenset({'(40, 50]', 'US', 'Virginie Boone'}),
#   frozenset({'(40, 50]', '@vboone', 'US'}),
#   frozenset({'(90, 95]', 'Sonoma', 'US'}),
#   frozenset({'(40, 50]', '@vboone', 'California'}),
#   frozenset({'Russian River Valley', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'California', 'Russian River Valley', 'Sonoma'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Sonoma'}),
#   frozenset({'California', 'Russian River Valley', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Russian River Valley'}),
#   frozenset({'Russian River Valley', 'US', 'Virginie Boone'}),
#   frozenset({'California', 'Russian River Valley', 'US'}),
#   frozenset({'@vboone', 'Russian River Valley', 'US'}),
#   frozenset({'Russian River Valley', 'Sonoma', 'US'}),
#   frozenset({'(90, 95]', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'(90, 95]', 'California', 'Sonoma'}),
#   frozenset({'(90, 95]', '@vboone', 'Sonoma'}),
#   frozenset({'(40, 50]', 'California', 'Virginie Boone'}),
#   frozenset({'(40, 50]', '@vboone', 'Virginie Boone'}),
#   frozenset({'(40, 50]', 'California', 'US'}),
#   frozenset({'(40, 50]', '(90, 95]', 'US'}),
#   frozenset({'(40, 50]', '(90, 95]', 'California'}),
#   frozenset({'(50, 60]', '(90, 95]', 'US'}),
#   frozenset({'(20, 30]', '(90, 95]', 'US'}),
#   frozenset({'(30, 40]', '(90, 95]', 'US'}),
#   frozenset({'(90, 95]', 'California', 'Matt Kettmann'}),
#   frozenset({'(90, 95]', 'California', 'Central Coast'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'California'}),
#   frozenset({'(90, 95]', 'Matt Kettmann', 'US'}),
#   frozenset({'(90, 95]', 'Central Coast', 'US'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'US'}),
#   frozenset({'(90, 95]', 'Central Coast', 'Matt Kettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Matt Kettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Central Coast'}),
#   frozenset({'(90, 95]', 'Pinot Noir', 'US'}),
#   frozenset({'(90, 95]', 'California', 'Pinot Noir'}),
#   frozenset({'Matt Kettmann', 'Pinot Noir', 'US'}),
#   frozenset({'California', 'Matt Kettmann', 'Pinot Noir'}),
#   frozenset({'Central Coast', 'Pinot Noir', 'US'}),
#   frozenset({'California', 'Central Coast', 'Pinot Noir'}),
#   frozenset({'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#   frozenset({'@mattkettmann', 'Pinot Noir', 'US'}),
#   frozenset({'@mattkettmann', 'California', 'Pinot Noir'}),
#   frozenset({'@mattkettmann', 'Matt Kettmann', 'Pinot Noir'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Pinot Noir'}),
#   frozenset({'(90, 95]', 'California', 'Virginie Boone'}),
#   frozenset({'(90, 95]', '@vboone', 'Virginie Boone'}),
#   frozenset({'(90, 95]', '@vboone', 'California'}),
#   frozenset({'(60, 2100]', '(90, 95]', 'US'}),
#   frozenset({'(90, 95]', 'US', 'Virginie Boone'}),
#   frozenset({'(90, 95]', 'California', 'US'}),
#   frozenset({'(90, 95]', '@vboone', 'US'}),
#   frozenset({'(60, 2100]', '(90, 95]', 'California'}),
#   frozenset({'(85, 90]', 'Red Blend', 'US'}),
#   frozenset({'(20, 30]', 'US', 'Virginie Boone'}),
#   frozenset({'(20, 30]', '@vboone', 'US'}),
#   frozenset({'(20, 30]', 'California', 'Virginie Boone'}),
#   frozenset({'(20, 30]', '@vboone', 'California'}),
#   frozenset({'(20, 30]', '@vboone', 'Virginie Boone'}),
#   frozenset({'(20, 30]', 'Paul Gregutt', 'US'}),
#   frozenset({'(20, 30]', '@paulgwine\xa0', 'US'}),
#   frozenset({'(20, 30]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   frozenset({'(50, 60]', 'California', 'US'}),
#   frozenset({'(30, 40]', 'California', 'Virginie Boone'}),
#   frozenset({'(30, 40]', '@vboone', 'Virginie Boone'}),
#   frozenset({'(30, 40]', '@vboone', 'California'}),
#   frozenset({'(30, 40]', '(85, 90]', 'California'}),
#   frozenset({'(30, 40]', '(85, 90]', 'US'}),
#   frozenset({'(30, 40]', 'US', 'Virginie Boone'}),
#   frozenset({'(30, 40]', 'California', 'US'}),
#   frozenset({'(30, 40]', '@vboone', 'US'}),
#   frozenset({'Columbia Valley (WA)', 'Sean P. Sullivan', 'Washington'}),
#   frozenset({'Columbia Valley', 'Sean P. Sullivan', 'Washington'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Washington'}),
#   frozenset({'@wawinereport', 'Sean P. Sullivan', 'Washington'}),
#   frozenset({'@wawinereport', 'Columbia Valley (WA)', 'Washington'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'Washington'}),
#   frozenset({'(20, 30]', 'Columbia Valley', 'Washington'}),
#   frozenset({'(85, 90]', 'US', 'Washington'}),
#   frozenset({'(20, 30]', 'US', 'Washington'}),
#   frozenset({'(85, 90]', 'Sean P. Sullivan', 'Washington'}),
#   frozenset({'(85, 90]', 'Columbia Valley (WA)', 'Washington'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Washington'}),
#   frozenset({'(85, 90]', '@wawinereport', 'Washington'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Sean P. Sullivan'}),
#   frozenset({'@wawinereport', 'Columbia Valley (WA)', 'Sean P. Sullivan'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'Sean P. Sullivan'}),
#   frozenset({'(85, 90]', 'Sean P. Sullivan', 'US'}),
#   frozenset({'Sean P. Sullivan', 'US', 'Washington'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Sean P. Sullivan'}),
#   frozenset({'(85, 90]', '@wawinereport', 'Sean P. Sullivan'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'Columbia Valley (WA)'}),
#   frozenset({'(85, 90]', 'Columbia Valley (WA)', 'US'}),
#   frozenset({'Columbia Valley (WA)', 'US', 'Washington'}),
#   frozenset({'Columbia Valley (WA)', 'Sean P. Sullivan', 'US'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'US'}),
#   frozenset({'(20, 30]', 'Columbia Valley', 'US'}),
#   frozenset({'Columbia Valley', 'US', 'Washington'}),
#   frozenset({'Columbia Valley', 'Sean P. Sullivan', 'US'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'US'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Columbia Valley (WA)'}),
#   frozenset({'(85, 90]', '@wawinereport', 'US'}),
#   frozenset({'@wawinereport', 'US', 'Washington'}),
#   frozenset({'@wawinereport', 'Sean P. Sullivan', 'US'}),
#   frozenset({'@wawinereport', 'Columbia Valley (WA)', 'US'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'US'}),
#   frozenset({'(85, 90]', '@wawinereport', 'Columbia Valley'}),
#   frozenset({'(40, 50]', '(85, 90]', 'US'}),
#   frozenset({'(40, 50]', 'Pinot Noir', 'US'}),
#   frozenset({'(60, 2100]', 'US', 'Virginie Boone'}),
#   frozenset({'(60, 2100]', 'California', 'US'}),
#   frozenset({'(60, 2100]', '@vboone', 'US'}),
#   frozenset({'California', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Sonoma'}),
#   frozenset({'(85, 90]', 'Sonoma', 'US'}),
#   frozenset({'Sonoma', 'US', 'Virginie Boone'}),
#   frozenset({'California', 'Sonoma', 'US'}),
#   frozenset({'@vboone', 'Sonoma', 'US'}),
#   frozenset({'Pinot Noir', 'Sonoma', 'US'}),
#   frozenset({'(85, 90]', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'(85, 90]', 'California', 'Sonoma'}),
#   frozenset({'(85, 90]', '@vboone', 'Sonoma'}),
#   frozenset({'Pinot Noir', 'US', 'Virginie Boone'}),
#   frozenset({'Pinot Noir', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'California', 'Pinot Noir', 'US'}),
#   frozenset({'California', 'Pinot Noir', 'Sonoma'}),
#   frozenset({'California', 'Pinot Noir', 'Virginie Boone'}),
#   frozenset({'(60, 2100]', 'California', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Pinot Noir', 'US'}),
#   frozenset({'@vboone', 'Pinot Noir', 'Sonoma'}),
#   frozenset({'@vboone', 'Pinot Noir', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Pinot Noir'}),
#   frozenset({'(60, 2100]', '@vboone', 'Virginie Boone'}),
#   frozenset({'(60, 2100]', '@vboone', 'California'}),
#   frozenset({'(85, 90]', 'California', 'Matt Kettmann'}),
#   frozenset({'(85, 90]', 'Matt Kettmann', 'US'}),
#   frozenset({'California', 'Matt Kettmann', 'US'}),
#   frozenset({'(85, 90]', 'Central Coast', 'Matt Kettmann'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Matt Kettmann'}),
#   frozenset({'(85, 90]', 'California', 'Central Coast'}),
#   frozenset({'California', 'Central Coast', 'Matt Kettmann'}),
#   frozenset({'(85, 90]', 'Central Coast', 'US'}),
#   frozenset({'California', 'Central Coast', 'US'}),
#   frozenset({'Central Coast', 'Matt Kettmann', 'US'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'California'}),
#   frozenset({'@mattkettmann', 'California', 'Matt Kettmann'}),
#   frozenset({'@mattkettmann', 'California', 'Central Coast'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'US'}),
#   frozenset({'@mattkettmann', 'California', 'US'}),
#   frozenset({'@mattkettmann', 'Matt Kettmann', 'US'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'US'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'Matt Kettmann'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'Central Coast'}),
#   frozenset({'(20, 30]', '(85, 90]', 'US'}),
#   frozenset({'(20, 30]', 'California', 'US'}),
#   frozenset({'(20, 30]', '(85, 90]', 'California'}),
#   frozenset({'California', 'Napa Valley', 'Virginie Boone'}),
#   frozenset({'Cabernet Sauvignon', 'California', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Napa Valley', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Cabernet Sauvignon', 'Virginie Boone'}),
#   frozenset({'(85, 90]', 'US', 'Virginie Boone'}),
#   frozenset({'(85, 90]', 'California', 'Virginie Boone'}),
#   frozenset({'(85, 90]', '@vboone', 'Virginie Boone'}),
#   frozenset({'Napa', 'Napa Valley', 'Virginie Boone'}),
#   frozenset({'Napa Valley', 'US', 'Virginie Boone'}),
#   frozenset({'California', 'Napa', 'Virginie Boone'}),
#   frozenset({'California', 'Napa', 'Napa Valley'}),
#   frozenset({'@vboone', 'Napa', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Napa', 'Napa Valley'}),
#   frozenset({'@vboone', 'California', 'Napa'}),
#   frozenset({'Napa', 'US', 'Virginie Boone'}),
#   frozenset({'Napa', 'Napa Valley', 'US'}),
#   frozenset({'California', 'Napa', 'US'}),
#   frozenset({'@vboone', 'Napa', 'US'}),
#   frozenset({'@vboone', 'California', 'Napa Valley'}),
#   frozenset({'@vboone', 'Cabernet Sauvignon', 'California'}),
#   frozenset({'(85, 90]', 'California', 'US'}),
#   frozenset({'California', 'US', 'Virginie Boone'}),
#   frozenset({'California', 'Napa Valley', 'US'}),
#   frozenset({'(85, 90]', '@vboone', 'California'}),
#   frozenset({'(85, 90]', 'Cabernet Sauvignon', 'US'}),
#   frozenset({'Cabernet Sauvignon', 'US', 'Virginie Boone'}),
#   frozenset({'Cabernet Sauvignon', 'California', 'US'}),
#   frozenset({'(85, 90]', '@vboone', 'US'}),
#   frozenset({'@vboone', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Napa Valley', 'US'}),
#   frozenset({'@vboone', 'California', 'US'}),
#   frozenset({'@vboone', 'Cabernet Sauvignon', 'US'}),
#   frozenset({'(0, 20]', '(85, 90]', 'US'}),
#   frozenset({'(0, 20]', 'California', 'US'}),
#   frozenset({'(0, 20]', '(85, 90]', 'California'}),
#   frozenset({'Pinot Noir', 'US', 'Willamette Valley'}),
#   frozenset({'Paul Gregutt', 'US', 'Willamette Valley'}),
#   frozenset({'Paul Gregutt', 'Pinot Noir', 'Willamette Valley'}),
#   frozenset({'Oregon', 'US', 'Willamette Valley'}),
#   frozenset({'Oregon', 'Pinot Noir', 'Willamette Valley'}),
#   frozenset({'Oregon', 'Paul Gregutt', 'Willamette Valley'}),
#   frozenset({'(85, 90]', 'US', 'Willamette Valley'}),
#   frozenset({'(85, 90]', 'Paul Gregutt', 'Willamette Valley'}),
#   frozenset({'(85, 90]', 'Oregon', 'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0', 'US', 'Willamette Valley'}),
#   frozenset({'(85, 90]', 'Paul Gregutt', 'US'}),
#   frozenset({'Paul Gregutt', 'Pinot Noir', 'US'}),
#   frozenset({'Oregon', 'Pinot Noir', 'US'}),
#   frozenset({'@paulgwine\xa0', 'Pinot Noir', 'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0', 'Pinot Noir', 'US'}),
#   frozenset({'(85, 90]', 'Pinot Noir', 'US'}),
#   frozenset({'Oregon', 'Paul Gregutt', 'US'}),
#   frozenset({'Oregon', 'Paul Gregutt', 'Pinot Noir'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Pinot Noir'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'US'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Pinot Noir'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt'}),
#   frozenset({'(85, 90]', 'Oregon', 'US'}),
#   frozenset({'(85, 90]', 'Oregon', 'Paul Gregutt'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Willamette Valley'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'US'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon'})],
#  [frozenset({'(90, 95]', 'Columbia Valley', 'US', 'Washington'}),
#   frozenset({'(30, 40]', 'Columbia Valley', 'US', 'Washington'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Paul Gregutt', 'US'}),
#   frozenset({'(0, 20]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Columbia Valley', 'Paul Gregutt'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Columbia Valley', 'US'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Paul Gregutt', 'US'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Washington'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'Paul Gregutt', 'US'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'US'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Columbia Valley', 'Washington'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'Washington'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'Washington'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Paul Gregutt', 'Washington'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'US', 'Washington'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'US', 'Washington'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'US', 'Washington'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'US', 'Washington'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Paul Gregutt', 'Washington'}),
#   frozenset({'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'Washington'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Paul Gregutt', 'US'}),
#   frozenset({'(0, 20]', 'Columbia Valley', 'US', 'Washington'}),
#   frozenset({'Columbia Valley', 'Paul Gregutt', 'US', 'Washington'}),
#   frozenset({'Columbia Valley (WA)', 'Paul Gregutt', 'US', 'Washington'}),
#   frozenset({'(85, 90]', 'Paul Gregutt', 'US', 'Washington'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Oregon', 'Paul Gregutt'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Oregon', 'US'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   frozenset({'(90, 95]', 'Oregon', 'Paul Gregutt', 'US'}),
#   frozenset({'(30, 40]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'California', 'US'}),
#   frozenset({'(85, 90]', 'California', 'Jim Gordon', 'US'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'Jim Gordon', 'US'}),
#   frozenset({'@gordone_cellars', 'California', 'Jim Gordon', 'US'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'California', 'Jim Gordon'}),
#   frozenset({'(40, 50]', '@vboone', 'California', 'US'}),
#   frozenset({'(40, 50]', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'(40, 50]', '@vboone', 'California', 'Virginie Boone'}),
#   frozenset({'(90, 95]', '@vboone', 'California', 'Sonoma'}),
#   frozenset({'(90, 95]', 'California', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'(90, 95]', '@vboone', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Sonoma', 'US'}),
#   frozenset({'@vboone', 'California', 'Russian River Valley', 'US'}),
#   frozenset({'California', 'Russian River Valley', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone',
#              'California',
#              'Russian River Valley',
#              'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Russian River Valley', 'Sonoma'}),
#   frozenset({'California',
#              'Russian River Valley',
#              'Sonoma',
#              'Virginie Boone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'(90, 95]', '@vboone', 'Sonoma', 'US'}),
#   frozenset({'(40, 50]', '@vboone', 'US', 'Virginie Boone'}),
#   frozenset({'(40, 50]', '(90, 95]', 'California', 'US'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'California', 'US'}),
#   frozenset({'(90, 95]', 'California', 'Central Coast', 'US'}),
#   frozenset({'(90, 95]', 'California', 'Matt Kettmann', 'US'}),
#   frozenset({'@mattkettmann', 'California', 'Pinot Noir', 'US'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#   frozenset({'@mattkettmann', 'California', 'Central Coast', 'Pinot Noir'}),
#   frozenset({'California', 'Central Coast', 'Pinot Noir', 'US'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Pinot Noir', 'US'}),
#   frozenset({'@mattkettmann', 'California', 'Matt Kettmann', 'Pinot Noir'}),
#   frozenset({'California', 'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#   frozenset({'California', 'Matt Kettmann', 'Pinot Noir', 'US'}),
#   frozenset({'@mattkettmann', 'Matt Kettmann', 'Pinot Noir', 'US'}),
#   frozenset({'Central Coast', 'Matt Kettmann', 'Pinot Noir', 'US'}),
#   frozenset({'(90, 95]', 'California', 'Pinot Noir', 'US'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Central Coast', 'Matt Kettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Central Coast', 'US'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Matt Kettmann', 'US'}),
#   frozenset({'(90, 95]', 'Central Coast', 'Matt Kettmann', 'US'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'California', 'Central Coast'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'California', 'Matt Kettmann'}),
#   frozenset({'(90, 95]', 'California', 'Central Coast', 'Matt Kettmann'}),
#   frozenset({'(90, 95]', '@vboone', 'California', 'US'}),
#   frozenset({'(90, 95]', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'(60, 2100]', '(90, 95]', 'California', 'US'}),
#   frozenset({'(90, 95]', '@vboone', 'US', 'Virginie Boone'}),
#   frozenset({'(90, 95]', '@vboone', 'California', 'Virginie Boone'}),
#   frozenset({'(20, 30]', '@vboone', 'California', 'Virginie Boone'}),
#   frozenset({'(20, 30]', '@vboone', 'California', 'US'}),
#   frozenset({'(20, 30]', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'(20, 30]', '@vboone', 'US', 'Virginie Boone'}),
#   frozenset({'(20, 30]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   frozenset({'(30, 40]', '@vboone', 'California', 'US'}),
#   frozenset({'(30, 40]', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'(30, 40]', '(85, 90]', 'California', 'US'}),
#   frozenset({'(30, 40]', '@vboone', 'US', 'Virginie Boone'}),
#   frozenset({'(30, 40]', '@vboone', 'California', 'Virginie Boone'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'US'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'Sean P. Sullivan', 'US'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'US', 'Washington'}),
#   frozenset({'(85, 90]', '@wawinereport', 'Columbia Valley', 'US'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'US'}),
#   frozenset({'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'US'}),
#   frozenset({'@wawinereport', 'Columbia Valley (WA)', 'US', 'Washington'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'US', 'Washington'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Columbia Valley (WA)', 'US'}),
#   frozenset({'(85, 90]',
#              '@wawinereport',
#              'Columbia Valley',
#              'Sean P. Sullivan'}),
#   frozenset({'@wawinereport', 'Sean P. Sullivan', 'US', 'Washington'}),
#   frozenset({'Columbia Valley', 'Sean P. Sullivan', 'US', 'Washington'}),
#   frozenset({'Columbia Valley (WA)', 'Sean P. Sullivan', 'US', 'Washington'}),
#   frozenset({'(85, 90]', '@wawinereport', 'Sean P. Sullivan', 'US'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Sean P. Sullivan', 'US'}),
#   frozenset({'(85, 90]', 'Sean P. Sullivan', 'US', 'Washington'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan'}),
#   frozenset({'(85, 90]', '@wawinereport', 'Columbia Valley', 'Washington'}),
#   frozenset({'(85, 90]',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Washington'}),
#   frozenset({'(20, 30]', 'Columbia Valley', 'US', 'Washington'}),
#   frozenset({'(85, 90]', '@wawinereport', 'US', 'Washington'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'US', 'Washington'}),
#   frozenset({'(85, 90]', 'Columbia Valley (WA)', 'US', 'Washington'}),
#   frozenset({'(85, 90]', '@wawinereport', 'Sean P. Sullivan', 'Washington'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Washington'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Sean P. Sullivan', 'Washington'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Sean P. Sullivan',
#              'Washington'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'Washington'}),
#   frozenset({'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'Washington'}),
#   frozenset({'(60, 2100]', '@vboone', 'California', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Pinot Noir', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Pinot Noir', 'Sonoma'}),
#   frozenset({'California', 'Pinot Noir', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Pinot Noir', 'US'}),
#   frozenset({'@vboone', 'Pinot Noir', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Pinot Noir', 'US', 'Virginie Boone'}),
#   frozenset({'California', 'Pinot Noir', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Pinot Noir', 'Sonoma', 'US'}),
#   frozenset({'California', 'Pinot Noir', 'Sonoma', 'US'}),
#   frozenset({'Pinot Noir', 'Sonoma', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Sonoma', 'US'}),
#   frozenset({'@vboone', 'Sonoma', 'US', 'Virginie Boone'}),
#   frozenset({'California', 'Sonoma', 'US', 'Virginie Boone'}),
#   frozenset({'(85, 90]', '@vboone', 'Sonoma', 'US'}),
#   frozenset({'(85, 90]', 'California', 'Sonoma', 'US'}),
#   frozenset({'(85, 90]', 'Sonoma', 'US', 'Virginie Boone'}),
#   frozenset({'(85, 90]', '@vboone', 'California', 'Sonoma'}),
#   frozenset({'(85, 90]', '@vboone', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'(85, 90]', 'California', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'(60, 2100]', '@vboone', 'California', 'US'}),
#   frozenset({'(60, 2100]', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'(60, 2100]', '@vboone', 'US', 'Virginie Boone'}),
#   frozenset({'(20, 30]', '(85, 90]', 'California', 'US'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'California', 'US'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'Central Coast', 'US'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'California', 'Central Coast'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Matt Kettmann', 'US'}),
#   frozenset({'(85, 90]', 'California', 'Central Coast', 'US'}),
#   frozenset({'@mattkettmann', 'California', 'Central Coast', 'US'}),
#   frozenset({'@mattkettmann', 'California', 'Central Coast', 'Matt Kettmann'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'Central Coast', 'Matt Kettmann'}),
#   frozenset({'(85, 90]', 'California', 'Matt Kettmann', 'US'}),
#   frozenset({'@mattkettmann', 'California', 'Matt Kettmann', 'US'}),
#   frozenset({'California', 'Central Coast', 'Matt Kettmann', 'US'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'Matt Kettmann', 'US'}),
#   frozenset({'(85, 90]', 'Central Coast', 'Matt Kettmann', 'US'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'California', 'Matt Kettmann'}),
#   frozenset({'(85, 90]', 'California', 'Central Coast', 'Matt Kettmann'}),
#   frozenset({'(0, 20]', '(85, 90]', 'California', 'US'}),
#   frozenset({'@vboone', 'Cabernet Sauvignon', 'California', 'US'}),
#   frozenset({'@vboone', 'Cabernet Sauvignon', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Napa Valley', 'US'}),
#   frozenset({'@vboone', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'Cabernet Sauvignon', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'California', 'Napa Valley', 'US', 'Virginie Boone'}),
#   frozenset({'(85, 90]', '@vboone', 'California', 'US'}),
#   frozenset({'(85, 90]', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Napa', 'US'}),
#   frozenset({'@vboone', 'Napa', 'Napa Valley', 'US'}),
#   frozenset({'California', 'Napa', 'Napa Valley', 'US'}),
#   frozenset({'@vboone', 'Napa', 'US', 'Virginie Boone'}),
#   frozenset({'California', 'Napa', 'US', 'Virginie Boone'}),
#   frozenset({'Napa', 'Napa Valley', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Napa', 'Napa Valley'}),
#   frozenset({'@vboone', 'California', 'Napa', 'Virginie Boone'}),
#   frozenset({'California', 'Napa', 'Napa Valley', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Napa Valley', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Napa', 'Napa Valley', 'Virginie Boone'}),
#   frozenset({'(85, 90]', '@vboone', 'US', 'Virginie Boone'}),
#   frozenset({'(85, 90]', '@vboone', 'California', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Cabernet Sauvignon', 'California', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Napa Valley', 'Virginie Boone'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon', 'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'Pinot Noir'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon', 'US'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'US'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Pinot Noir', 'US'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon', 'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Pinot Noir', 'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'US', 'Willamette Valley'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Paul Gregutt',
#              'Willamette Valley'}),
#   frozenset({'(85, 90]', 'Oregon', 'Paul Gregutt', 'US'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Pinot Noir', 'US'}),
#   frozenset({'@paulgwine\xa0',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'Willamette Valley'}),
#   frozenset({'Oregon', 'Paul Gregutt', 'Pinot Noir', 'US'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'US', 'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'US', 'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0', 'Pinot Noir', 'US', 'Willamette Valley'}),
#   frozenset({'(85, 90]', 'Oregon', 'Paul Gregutt', 'Willamette Valley'}),
#   frozenset({'(85, 90]', 'Oregon', 'US', 'Willamette Valley'}),
#   frozenset({'Oregon', 'Paul Gregutt', 'Pinot Noir', 'Willamette Valley'}),
#   frozenset({'(85, 90]', 'Paul Gregutt', 'US', 'Willamette Valley'}),
#   frozenset({'Oregon', 'Paul Gregutt', 'US', 'Willamette Valley'}),
#   frozenset({'Oregon', 'Pinot Noir', 'US', 'Willamette Valley'}),
#   frozenset({'Paul Gregutt', 'Pinot Noir', 'US', 'Willamette Valley'})],
#  [frozenset({'(85, 90]',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   frozenset({'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Columbia Valley',
#              'US',
#              'Washington'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'US',
#              'Washington'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'Washington'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'Washington'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'US'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'US'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'US'}),
#   frozenset({'(85, 90]',
#              '@gordone_cellars',
#              'California',
#              'Jim Gordon',
#              'US'}),
#   frozenset({'(40, 50]', '@vboone', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'(90, 95]', '@vboone', 'Sonoma', 'US', 'Virginie Boone'}),
#   frozenset({'(90, 95]', '@vboone', 'California', 'Sonoma', 'US'}),
#   frozenset({'@vboone',
#              'California',
#              'Russian River Valley',
#              'Sonoma',
#              'Virginie Boone'}),
#   frozenset({'@vboone',
#              'California',
#              'Russian River Valley',
#              'US',
#              'Virginie Boone'}),
#   frozenset({'@vboone',
#              'Russian River Valley',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Russian River Valley', 'Sonoma', 'US'}),
#   frozenset({'(90, 95]', '@vboone', 'California', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'(90, 95]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann'}),
#   frozenset({'(90, 95]',
#              '@mattkettmann',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   frozenset({'@mattkettmann',
#              'Central Coast',
#              'Matt Kettmann',
#              'Pinot Noir',
#              'US'}),
#   frozenset({'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'Pinot Noir',
#              'US'}),
#   frozenset({'@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'Pinot Noir'}),
#   frozenset({'@mattkettmann',
#              'California',
#              'Matt Kettmann',
#              'Pinot Noir',
#              'US'}),
#   frozenset({'@mattkettmann',
#              'California',
#              'Central Coast',
#              'Pinot Noir',
#              'US'}),
#   frozenset({'(90, 95]',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   frozenset({'(90, 95]',
#              '@mattkettmann',
#              'California',
#              'Matt Kettmann',
#              'US'}),
#   frozenset({'(90, 95]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'US'}),
#   frozenset({'(90, 95]', '@vboone', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'(20, 30]', '@vboone', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'(30, 40]', '@vboone', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'Washington'}),
#   frozenset({'(85, 90]',
#              '@wawinereport',
#              'Columbia Valley',
#              'Sean P. Sullivan',
#              'Washington'}),
#   frozenset({'(85, 90]',
#              'Columbia Valley',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   frozenset({'(85, 90]',
#              '@wawinereport',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   frozenset({'(85, 90]',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'US',
#              'Washington'}),
#   frozenset({'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'US',
#              'Washington'}),
#   frozenset({'(85, 90]',
#              '@wawinereport',
#              'Columbia Valley',
#              'US',
#              'Washington'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   frozenset({'(85, 90]',
#              '@wawinereport',
#              'Columbia Valley',
#              'Sean P. Sullivan',
#              'US'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'US'}),
#   frozenset({'(60, 2100]', '@vboone', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'(85, 90]', '@vboone', 'California', 'Sonoma', 'Virginie Boone'}),
#   frozenset({'(85, 90]', 'California', 'Sonoma', 'US', 'Virginie Boone'}),
#   frozenset({'(85, 90]', '@vboone', 'Sonoma', 'US', 'Virginie Boone'}),
#   frozenset({'(85, 90]', '@vboone', 'California', 'Sonoma', 'US'}),
#   frozenset({'@vboone', 'California', 'Sonoma', 'US', 'Virginie Boone'}),
#   frozenset({'California', 'Pinot Noir', 'Sonoma', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Pinot Noir', 'Sonoma', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Pinot Noir', 'Sonoma', 'US'}),
#   frozenset({'@vboone', 'California', 'Pinot Noir', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone',
#              'California',
#              'Pinot Noir',
#              'Sonoma',
#              'Virginie Boone'}),
#   frozenset({'@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   frozenset({'(85, 90]',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   frozenset({'(85, 90]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann'}),
#   frozenset({'(85, 90]',
#              '@mattkettmann',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   frozenset({'(85, 90]',
#              '@mattkettmann',
#              'California',
#              'Matt Kettmann',
#              'US'}),
#   frozenset({'(85, 90]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'US'}),
#   frozenset({'@vboone',
#              'California',
#              'Napa',
#              'Napa Valley',
#              'Virginie Boone'}),
#   frozenset({'California', 'Napa', 'Napa Valley', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'Napa', 'Napa Valley', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Napa', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Napa', 'Napa Valley', 'US'}),
#   frozenset({'(85, 90]', '@vboone', 'California', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Napa Valley', 'US', 'Virginie Boone'}),
#   frozenset({'@vboone',
#              'Cabernet Sauvignon',
#              'California',
#              'US',
#              'Virginie Boone'}),
#   frozenset({'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   frozenset({'(85, 90]', 'Oregon', 'Paul Gregutt', 'US', 'Willamette Valley'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Paul Gregutt',
#              'US',
#              'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Oregon',
#              'US',
#              'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'Willamette Valley'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'US',
#              'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'Pinot Noir', 'US'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'US'})],
#  [frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   frozenset({'@vboone',
#              'California',
#              'Russian River Valley',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   frozenset({'(90, 95]',
#              '@vboone',
#              'California',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   frozenset({'@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'Pinot Noir',
#              'US'}),
#   frozenset({'(90, 95]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   frozenset({'(85, 90]',
#              '@wawinereport',
#              'Columbia Valley',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   frozenset({'@vboone',
#              'California',
#              'Pinot Noir',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   frozenset({'(85, 90]',
#              '@vboone',
#              'California',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   frozenset({'(85, 90]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   frozenset({'@vboone',
#              'California',
#              'Napa',
#              'Napa Valley',
#              'US',
#              'Virginie Boone'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'US',
#              'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'})],
#  []]

# %%
def select_conf(L,suppData,thredhold=0.8):
    confList = []
    for itemSet in L:
            for record in itemSet:
                if(len(record)>1): 
                    for i in record: 
                        tar = suppData[frozenset([i])]
                        bset = record - frozenset([i])
                        aset = suppData[record]
                        ret = suppData.get(bset)
                        try:
                            if suppData.get(bset):
                                con = aset/ret
                                if con > thredhold:
                                    confList.append([frozenset([i]),record,con])
                        except TypeError as e:
                            print(e)

    return confList

# %%
confList = select_conf(L,suppData)
def liftCheck(conList,suppData):
    liftList_true=[]
    liftList_no=[]
    liftList_false=[]
    for item in confList:
        score = suppData.get(item[1])/(suppData.get(item[0])*suppData.get(item[1]-item[0]))
        if score>1:
            liftList_true.append(item)
        if score<1:
            liftList_false.append(item)
        if score ==1:
            liftList_no.append(item)
    return liftList_true,liftList_no,liftList_false
select_conf(L,suppData)
yes,no,false = liftCheck(confList,suppData)
yes #查看正相关的关联规则
# Out:
# [[frozenset({'California'}),
#   frozenset({'@gordone_cellars', 'California'}),
#   1.0],
#  [frozenset({'California'}), frozenset({'California', 'Jim Gordon'}), 1.0],
#  [frozenset({'Jim Gordon'}),
#   frozenset({'@gordone_cellars', 'Jim Gordon'}),
#   1.0],
#  [frozenset({'@gordone_cellars'}),
#   frozenset({'@gordone_cellars', 'Jim Gordon'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Russian River Valley'}),
#   0.9761721752498077],
#  [frozenset({'California'}),
#   frozenset({'California', 'Russian River Valley'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'Russian River Valley', 'Virginie Boone'}),
#   0.9761721752498077],
#  [frozenset({'Sonoma'}), frozenset({'Russian River Valley', 'Sonoma'}), 1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@wawinereport', 'Columbia Valley'}),
#   0.9097408400357463],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)'}),
#   1.0],
#  [frozenset({'Sean P. Sullivan'}),
#   frozenset({'@wawinereport', 'Sean P. Sullivan'}),
#   1.0],
#  [frozenset({'@wawinereport'}),
#   frozenset({'@wawinereport', 'Sean P. Sullivan'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Sean P. Sullivan'}),
#   0.9097408400357463],
#  [frozenset({'Washington'}),
#   frozenset({'@wawinereport', 'Washington'}),
#   0.9633601429848079],
#  [frozenset({'Washington'}),
#   frozenset({'Columbia Valley', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Washington'}),
#   0.9464499572284003],
#  [frozenset({'Washington'}),
#   frozenset({'Columbia Valley (WA)', 'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'Sean P. Sullivan', 'Washington'}),
#   0.9633601429848079],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Sonoma'}),
#   0.9630402384500746],
#  [frozenset({'California'}), frozenset({'California', 'Sonoma'}), 1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'Sonoma', 'Virginie Boone'}),
#   0.9630402384500746],
#  [frozenset({'California'}), frozenset({'@mattkettmann', 'California'}), 1.0],
#  [frozenset({'California'}), frozenset({'California', 'Central Coast'}), 1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'Central Coast'}),
#   0.909575602473875],
#  [frozenset({'Central Coast'}),
#   frozenset({'@mattkettmann', 'Central Coast'}),
#   0.952221478008484],
#  [frozenset({'California'}), frozenset({'California', 'Matt Kettmann'}), 1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'@mattkettmann', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'Central Coast', 'Matt Kettmann'}),
#   0.909575602473875],
#  [frozenset({'Central Coast'}),
#   frozenset({'Central Coast', 'Matt Kettmann'}),
#   0.952221478008484],
#  [frozenset({'California'}), frozenset({'@vboone', 'California'}), 1.0],
#  [frozenset({'@vboone'}), frozenset({'@vboone', 'Napa'}), 0.9823834196891194],
#  [frozenset({'California'}), frozenset({'California', 'Napa'}), 1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Napa Valley'}),
#   0.9765828274067649],
#  [frozenset({'California'}), frozenset({'California', 'Napa Valley'}), 1.0],
#  [frozenset({'Napa'}), frozenset({'Napa', 'Napa Valley'}), 0.9991326973113617],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}), frozenset({'@vboone', 'Virginie Boone'}), 1.0],
#  [frozenset({'California'}), frozenset({'California', 'Virginie Boone'}), 1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'Napa', 'Virginie Boone'}),
#   0.9823834196891194],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'Napa Valley', 'Virginie Boone'}),
#   0.9765828274067649],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Oregon'}),
#   0.9492691315563198],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'Oregon', 'Paul Gregutt'}),
#   0.9492691315563198],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Willamette Valley'}),
#   0.9865539761813292],
#  [frozenset({'Oregon'}), frozenset({'Oregon', 'Willamette Valley'}), 1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'Paul Gregutt', 'Willamette Valley'}),
#   0.9865539761813292],
#  [frozenset({'Washington'}),
#   frozenset({'(90, 95]', 'Columbia Valley', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(90, 95]', 'Columbia Valley', 'Washington'}),
#   0.9653702717101759],
#  [frozenset({'Washington'}),
#   frozenset({'(30, 40]', 'Columbia Valley', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(30, 40]', 'Columbia Valley', 'Washington'}),
#   0.9587458745874586],
#  [frozenset({'Washington'}),
#   frozenset({'(0, 20]', 'Columbia Valley', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(0, 20]', 'Columbia Valley', 'Washington'}),
#   0.9093464511595221],
#  [frozenset({'Washington'}),
#   frozenset({'Columbia Valley (WA)', 'Paul Gregutt', 'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'Columbia Valley', 'Paul Gregutt', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Paul Gregutt', 'Washington'}),
#   0.9490030674846626],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Washington'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Washington'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Washington'}),
#   0.9490030674846626],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Columbia Valley (WA)'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(0, 20]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(0, 20]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(90, 95]', 'Oregon', 'Paul Gregutt'}),
#   0.970183486238532],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Oregon'}),
#   0.970183486238532],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(30, 40]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(30, 40]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Jim Gordon'}),
#   frozenset({'@gordone_cellars', 'California', 'Jim Gordon'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@gordone_cellars', 'California', 'Jim Gordon'}),
#   1.0],
#  [frozenset({'@gordone_cellars'}),
#   frozenset({'@gordone_cellars', 'California', 'Jim Gordon'}),
#   1.0],
#  [frozenset({'Jim Gordon'}),
#   frozenset({'@gordone_cellars', 'Jim Gordon', 'US'}),
#   1.0],
#  [frozenset({'@gordone_cellars'}),
#   frozenset({'@gordone_cellars', 'Jim Gordon', 'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'California', 'Jim Gordon', 'US'}),
#   1.0],
#  [frozenset({'Jim Gordon'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'Jim Gordon'}),
#   1.0],
#  [frozenset({'@gordone_cellars'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'Jim Gordon'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]', 'California', 'Jim Gordon'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'California'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@gordone_cellars', 'California', 'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(40, 50]', '@vboone', 'California'}),
#   1.0],
#  [frozenset({'Sonoma'}),
#   frozenset({'Russian River Valley', 'Sonoma', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'Russian River Valley', 'Sonoma', 'Virginie Boone'}),
#   0.9761721752498077],
#  [frozenset({'Sonoma'}),
#   frozenset({'California', 'Russian River Valley', 'Sonoma'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'California', 'Russian River Valley', 'Sonoma'}),
#   1.0],
#  [frozenset({'Sonoma'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Sonoma'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Sonoma'}),
#   0.9761721752498077],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'California', 'Russian River Valley', 'Virginie Boone'}),
#   0.9761721752498077],
#  [frozenset({'California'}),
#   frozenset({'California', 'Russian River Valley', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@vboone', 'California', 'Russian River Valley'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'California', 'Russian River Valley'}),
#   0.9761721752498077],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'Russian River Valley', 'US', 'Virginie Boone'}),
#   0.9761721752498077],
#  [frozenset({'California'}),
#   frozenset({'California', 'Russian River Valley', 'US'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'US'}),
#   0.9761721752498077],
#  [frozenset({'Sonoma'}),
#   frozenset({'Russian River Valley', 'Sonoma', 'US'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(90, 95]', 'Sonoma', 'Virginie Boone'}),
#   0.953125],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', 'California', 'Sonoma'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(90, 95]', '@vboone', 'Sonoma'}),
#   0.953125],
#  [frozenset({'California'}),
#   frozenset({'(40, 50]', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(40, 50]', '@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(40, 50]', '@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', 'California', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', 'California', 'Central Coast'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'California'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'(90, 95]', 'Central Coast', 'Matt Kettmann'}),
#   0.9569105691056911],
#  [frozenset({'Central Coast'}),
#   frozenset({'(90, 95]', 'Central Coast', 'Matt Kettmann'}),
#   0.9675297986025484],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Central Coast'}),
#   0.9569105691056911],
#  [frozenset({'Central Coast'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Central Coast'}),
#   0.9675297986025484],
#  [frozenset({'California'}),
#   frozenset({'California', 'Matt Kettmann', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'California', 'Central Coast', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#   0.988313856427379],
#  [frozenset({'Central Coast'}),
#   frozenset({'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#   0.9842061512884456],
#  [frozenset({'California'}),
#   frozenset({'@mattkettmann', 'California', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'@mattkettmann', 'Matt Kettmann', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'Matt Kettmann', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Pinot Noir'}),
#   0.988313856427379],
#  [frozenset({'Central Coast'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Pinot Noir'}),
#   0.9842061512884456],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(90, 95]', '@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(90, 95]', '@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', '@vboone', 'California'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(20, 30]', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(20, 30]', '@vboone', 'California'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(20, 30]', '@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(20, 30]', '@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(20, 30]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(20, 30]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(30, 40]', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(30, 40]', '@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(30, 40]', '@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(30, 40]', '@vboone', 'California'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'Columbia Valley (WA)', 'Sean P. Sullivan', 'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'Columbia Valley', 'Sean P. Sullivan', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Sean P. Sullivan', 'Washington'}),
#   0.9443413729128016],
#  [frozenset({'Washington'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'@wawinereport', 'Sean P. Sullivan', 'Washington'}),
#   0.9633601429848079],
#  [frozenset({'Sean P. Sullivan'}),
#   frozenset({'@wawinereport', 'Sean P. Sullivan', 'Washington'}),
#   1.0],
#  [frozenset({'@wawinereport'}),
#   frozenset({'@wawinereport', 'Sean P. Sullivan', 'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'@wawinereport', 'Columbia Valley (WA)', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'Washington'}),
#   0.9443413729128016],
#  [frozenset({'Washington'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'(20, 30]', 'Columbia Valley', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(20, 30]', 'Columbia Valley', 'Washington'}),
#   0.9461538461538461],
#  [frozenset({'Washington'}),
#   frozenset({'(85, 90]', 'Sean P. Sullivan', 'Washington'}),
#   0.9655831739961759],
#  [frozenset({'Washington'}),
#   frozenset({'(85, 90]', 'Columbia Valley (WA)', 'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Washington'}),
#   0.9386271087841768],
#  [frozenset({'Washington'}),
#   frozenset({'(85, 90]', '@wawinereport', 'Washington'}),
#   0.9655831739961759],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Sean P. Sullivan'}),
#   1.0],
#  [frozenset({'Sean P. Sullivan'}),
#   frozenset({'@wawinereport', 'Columbia Valley (WA)', 'Sean P. Sullivan'}),
#   1.0],
#  [frozenset({'@wawinereport'}),
#   frozenset({'@wawinereport', 'Columbia Valley (WA)', 'Sean P. Sullivan'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'Sean P. Sullivan'}),
#   0.9097408400357463],
#  [frozenset({'Sean P. Sullivan'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'Sean P. Sullivan'}),
#   1.0],
#  [frozenset({'@wawinereport'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'Sean P. Sullivan'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'Sean P. Sullivan', 'US', 'Washington'}),
#   0.9633601429848079],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Sean P. Sullivan'}),
#   0.9067877629063098],
#  [frozenset({'Sean P. Sullivan'}),
#   frozenset({'(85, 90]', '@wawinereport', 'Sean P. Sullivan'}),
#   1.0],
#  [frozenset({'@wawinereport'}),
#   frozenset({'(85, 90]', '@wawinereport', 'Sean P. Sullivan'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'Columbia Valley (WA)'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'Columbia Valley (WA)', 'US', 'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'Columbia Valley', 'US', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'US', 'Washington'}),
#   0.9464499572284003],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Sean P. Sullivan', 'US'}),
#   0.9097408400357463],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'US'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Columbia Valley (WA)'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'@wawinereport', 'US', 'Washington'}),
#   0.9633601429848079],
#  [frozenset({'Sean P. Sullivan'}),
#   frozenset({'@wawinereport', 'Sean P. Sullivan', 'US'}),
#   1.0],
#  [frozenset({'@wawinereport'}),
#   frozenset({'@wawinereport', 'Sean P. Sullivan', 'US'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@wawinereport', 'Columbia Valley', 'US'}),
#   0.9097408400357463],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(85, 90]', '@wawinereport', 'Columbia Valley'}),
#   0.9067877629063098],
#  [frozenset({'California'}),
#   frozenset({'California', 'Sonoma', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'California', 'Sonoma', 'Virginie Boone'}),
#   0.9630402384500746],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone', 'Sonoma', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Sonoma', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@vboone', 'California', 'Sonoma'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'California', 'Sonoma'}),
#   0.9630402384500746],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'Sonoma', 'US', 'Virginie Boone'}),
#   0.9630402384500746],
#  [frozenset({'California'}), frozenset({'California', 'Sonoma', 'US'}), 1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Sonoma', 'US'}),
#   0.9630402384500746],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(85, 90]', 'Sonoma', 'Virginie Boone'}),
#   0.9702489374620522],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]', 'California', 'Sonoma'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(85, 90]', '@vboone', 'Sonoma'}),
#   0.9702489374620522],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'Pinot Noir', 'Sonoma', 'Virginie Boone'}),
#   0.9583999999999999],
#  [frozenset({'Sonoma'}),
#   frozenset({'Pinot Noir', 'Sonoma', 'Virginie Boone'}),
#   0.8631123919308357],
#  [frozenset({'California'}),
#   frozenset({'California', 'Pinot Noir', 'Sonoma'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'California', 'Pinot Noir', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(60, 2100]', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Sonoma'}),
#   frozenset({'@vboone', 'Pinot Noir', 'Sonoma'}),
#   0.8631123919308357],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Pinot Noir', 'Sonoma'}),
#   0.9583999999999999],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone', 'Pinot Noir', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Pinot Noir', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@vboone', 'California', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(60, 2100]', '@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(60, 2100]', '@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(60, 2100]', '@vboone', 'California'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]', 'California', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'California', 'Matt Kettmann', 'US'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'(85, 90]', 'Central Coast', 'Matt Kettmann'}),
#   0.86962890625],
#  [frozenset({'Central Coast'}),
#   frozenset({'(85, 90]', 'Central Coast', 'Matt Kettmann'}),
#   0.9353991596638656],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'Central Coast'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Matt Kettmann'}),
#   0.952221478008484],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]', 'California', 'Central Coast'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'California', 'Central Coast', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'California', 'Central Coast', 'Matt Kettmann'}),
#   0.909575602473875],
#  [frozenset({'Central Coast'}),
#   frozenset({'California', 'Central Coast', 'Matt Kettmann'}),
#   0.952221478008484],
#  [frozenset({'California'}),
#   frozenset({'California', 'Central Coast', 'US'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'Central Coast', 'Matt Kettmann', 'US'}),
#   0.909575602473875],
#  [frozenset({'Central Coast'}),
#   frozenset({'Central Coast', 'Matt Kettmann', 'US'}),
#   0.952221478008484],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'California'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'@mattkettmann', 'California', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@mattkettmann', 'California', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'California', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@mattkettmann', 'California', 'Central Coast'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'California', 'Central Coast'}),
#   0.909575602473875],
#  [frozenset({'Central Coast'}),
#   frozenset({'@mattkettmann', 'California', 'Central Coast'}),
#   0.952221478008484],
#  [frozenset({'California'}),
#   frozenset({'@mattkettmann', 'California', 'US'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'@mattkettmann', 'Matt Kettmann', 'US'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'Matt Kettmann', 'US'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'US'}),
#   0.909575602473875],
#  [frozenset({'Central Coast'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'US'}),
#   0.952221478008484],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'Central Coast'}),
#   0.86962890625],
#  [frozenset({'Central Coast'}),
#   frozenset({'(85, 90]', '@mattkettmann', 'Central Coast'}),
#   0.9353991596638656],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'California', 'Napa Valley', 'Virginie Boone'}),
#   0.9765828274067649],
#  [frozenset({'California'}),
#   frozenset({'California', 'Napa Valley', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'Cabernet Sauvignon', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone', 'Napa Valley', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Napa Valley', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@vboone', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone', 'Cabernet Sauvignon', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Cabernet Sauvignon', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(85, 90]', '@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(85, 90]', '@vboone', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Napa'}),
#   frozenset({'Napa', 'Napa Valley', 'Virginie Boone'}),
#   0.9991119005328597],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'Napa', 'Napa Valley', 'Virginie Boone'}),
#   0.9765624999999999],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'Napa Valley', 'US', 'Virginie Boone'}),
#   0.9765828274067649],
#  [frozenset({'California'}),
#   frozenset({'California', 'Napa', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'California', 'Napa', 'Virginie Boone'}),
#   0.9823834196891194],
#  [frozenset({'Napa'}),
#   frozenset({'California', 'Napa', 'Napa Valley'}),
#   0.9991326973113617],
#  [frozenset({'California'}),
#   frozenset({'California', 'Napa', 'Napa Valley'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone', 'Napa', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Napa', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Napa'}),
#   frozenset({'@vboone', 'Napa', 'Napa Valley'}),
#   0.9991119005328597],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Napa', 'Napa Valley'}),
#   0.9765624999999999],
#  [frozenset({'California'}),
#   frozenset({'@vboone', 'California', 'Napa'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'California', 'Napa'}),
#   0.9823834196891194],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'Napa', 'US', 'Virginie Boone'}),
#   0.9823834196891194],
#  [frozenset({'Napa'}),
#   frozenset({'Napa', 'Napa Valley', 'US'}),
#   0.9991326973113617],
#  [frozenset({'California'}), frozenset({'California', 'Napa', 'US'}), 1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Napa', 'US'}),
#   0.9823834196891194],
#  [frozenset({'California'}),
#   frozenset({'@vboone', 'California', 'Napa Valley'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'California', 'Napa Valley'}),
#   0.9765828274067649],
#  [frozenset({'California'}),
#   frozenset({'@vboone', 'Cabernet Sauvignon', 'California'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'California', 'US', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'California', 'Napa Valley', 'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]', '@vboone', 'California'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone', 'US', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}), frozenset({'@vboone', 'US', 'Virginie Boone'}), 1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Napa Valley', 'US'}),
#   0.9765828274067649],
#  [frozenset({'California'}), frozenset({'@vboone', 'California', 'US'}), 1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'Paul Gregutt', 'US', 'Willamette Valley'}),
#   0.9865539761813292],
#  [frozenset({'Willamette Valley'}),
#   frozenset({'Paul Gregutt', 'Pinot Noir', 'Willamette Valley'}),
#   0.9296128707893415],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'Paul Gregutt', 'Pinot Noir', 'Willamette Valley'}),
#   0.9824654622741765],
#  [frozenset({'Oregon'}),
#   frozenset({'Oregon', 'US', 'Willamette Valley'}),
#   1.0],
#  [frozenset({'Willamette Valley'}),
#   frozenset({'Oregon', 'Pinot Noir', 'Willamette Valley'}),
#   0.920743639921722],
#  [frozenset({'Oregon'}),
#   frozenset({'Oregon', 'Pinot Noir', 'Willamette Valley'}),
#   1.0],
#  [frozenset({'Oregon'}),
#   frozenset({'Oregon', 'Paul Gregutt', 'Willamette Valley'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'Oregon', 'Paul Gregutt', 'Willamette Valley'}),
#   0.9865539761813292],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(85, 90]', 'Paul Gregutt', 'Willamette Valley'}),
#   0.9828869047619048],
#  [frozenset({'Oregon'}),
#   frozenset({'(85, 90]', 'Oregon', 'Willamette Valley'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'US', 'Willamette Valley'}),
#   0.9865539761813292],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Pinot Noir', 'Willamette Valley'}),
#   0.9824654622741765],
#  [frozenset({'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0', 'Pinot Noir', 'Willamette Valley'}),
#   0.9296128707893415],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'Oregon', 'Paul Gregutt', 'US'}),
#   0.9492691315563198],
#  [frozenset({'Oregon'}),
#   frozenset({'Oregon', 'Paul Gregutt', 'Pinot Noir'}),
#   0.9989944695827049],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'Oregon', 'Paul Gregutt', 'Pinot Noir'}),
#   0.9721135029354208],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Willamette Valley'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Willamette Valley'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Willamette Valley'}),
#   0.9865539761813292],
#  [frozenset({'Oregon'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Willamette Valley'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'US'}),
#   0.9492691315563198],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Pinot Noir'}),
#   0.9721135029354208],
#  [frozenset({'Oregon'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Pinot Noir'}),
#   0.9989944695827049],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(85, 90]', 'Oregon', 'Paul Gregutt'}),
#   0.9436997319034852],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Willamette Valley'}),
#   0.9828869047619048],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon'}),
#   0.9436997319034852],
#  [frozenset({'Washington'}),
#   frozenset({'(90, 95]', 'Columbia Valley', 'US', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(90, 95]', 'Columbia Valley', 'US', 'Washington'}),
#   0.9653702717101759],
#  [frozenset({'Washington'}),
#   frozenset({'(30, 40]', 'Columbia Valley', 'US', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(30, 40]', 'Columbia Valley', 'US', 'Washington'}),
#   0.9587458745874586],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(0, 20]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(0, 20]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Columbia Valley', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Columbia Valley', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Washington'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'US'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Columbia Valley', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Columbia Valley', 'Washington'}),
#   0.9379407616361071],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'Washington'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'Washington'}),
#   0.9490030674846626],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'Washington'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'Washington'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Paul Gregutt', 'Washington'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Paul Gregutt', 'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'US', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley', 'US', 'Washington'}),
#   0.9490030674846626],
#  [frozenset({'Washington'}),
#   frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'US', 'Washington'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'US', 'Washington'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'US', 'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Paul Gregutt', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(85, 90]', 'Columbia Valley', 'Paul Gregutt', 'Washington'}),
#   0.9379407616361071],
#  [frozenset({'Washington'}),
#   frozenset({'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'(0, 20]', 'Columbia Valley', 'US', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(0, 20]', 'Columbia Valley', 'US', 'Washington'}),
#   0.9093464511595221],
#  [frozenset({'Washington'}),
#   frozenset({'Columbia Valley', 'Paul Gregutt', 'US', 'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'Columbia Valley', 'Paul Gregutt', 'US', 'Washington'}),
#   0.9490030674846626],
#  [frozenset({'Washington'}),
#   frozenset({'Columbia Valley (WA)', 'Paul Gregutt', 'US', 'Washington'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Oregon', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Oregon', 'Paul Gregutt'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Oregon', 'US'}),
#   0.970183486238532],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(90, 95]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(90, 95]', 'Oregon', 'Paul Gregutt', 'US'}),
#   0.970183486238532],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(30, 40]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(30, 40]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'California', 'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]', 'California', 'Jim Gordon', 'US'}),
#   1.0],
#  [frozenset({'Jim Gordon'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'Jim Gordon', 'US'}),
#   1.0],
#  [frozenset({'@gordone_cellars'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'Jim Gordon', 'US'}),
#   1.0],
#  [frozenset({'Jim Gordon'}),
#   frozenset({'@gordone_cellars', 'California', 'Jim Gordon', 'US'}),
#   1.0],
#  [frozenset({'@gordone_cellars'}),
#   frozenset({'@gordone_cellars', 'California', 'Jim Gordon', 'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@gordone_cellars', 'California', 'Jim Gordon', 'US'}),
#   1.0],
#  [frozenset({'Jim Gordon'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'California', 'Jim Gordon'}),
#   1.0],
#  [frozenset({'@gordone_cellars'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'California', 'Jim Gordon'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]', '@gordone_cellars', 'California', 'Jim Gordon'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(40, 50]', '@vboone', 'California', 'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(40, 50]', 'California', 'US', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(40, 50]', '@vboone', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(40, 50]', '@vboone', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(40, 50]', '@vboone', 'California', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(90, 95]', '@vboone', 'California', 'Sonoma'}),
#   0.953125],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', '@vboone', 'California', 'Sonoma'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(90, 95]', 'California', 'Sonoma', 'Virginie Boone'}),
#   0.953125],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', 'California', 'Sonoma', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(90, 95]', '@vboone', 'Sonoma', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(90, 95]', '@vboone', 'Sonoma', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Sonoma', 'US'}),
#   0.9761721752498077],
#  [frozenset({'Sonoma'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Sonoma', 'US'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'California', 'Russian River Valley', 'US'}),
#   0.9761721752498077],
#  [frozenset({'California'}),
#   frozenset({'@vboone', 'California', 'Russian River Valley', 'US'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'California', 'Russian River Valley', 'US', 'Virginie Boone'}),
#   0.9761721752498077],
#  [frozenset({'California'}),
#   frozenset({'California', 'Russian River Valley', 'US', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'US', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'US', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@vboone',
#              'California',
#              'Russian River Valley',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone',
#              'California',
#              'Russian River Valley',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone',
#              'California',
#              'Russian River Valley',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'California', 'Russian River Valley', 'Sonoma'}),
#   0.9761721752498077],
#  [frozenset({'Sonoma'}),
#   frozenset({'@vboone', 'California', 'Russian River Valley', 'Sonoma'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@vboone', 'California', 'Russian River Valley', 'Sonoma'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'California',
#              'Russian River Valley',
#              'Sonoma',
#              'Virginie Boone'}),
#   0.9761721752498077],
#  [frozenset({'Sonoma'}),
#   frozenset({'California',
#              'Russian River Valley',
#              'Sonoma',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'California',
#              'Russian River Valley',
#              'Sonoma',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Sonoma', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Sonoma'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Sonoma', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone', 'Russian River Valley', 'Sonoma', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(90, 95]', '@vboone', 'Sonoma', 'US'}),
#   0.953125],
#  [frozenset({'@vboone'}),
#   frozenset({'(40, 50]', '@vboone', 'US', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(40, 50]', '@vboone', 'US', 'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'California', 'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', 'California', 'Central Coast', 'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', 'California', 'Matt Kettmann', 'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@mattkettmann', 'California', 'Pinot Noir', 'US'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'Central Coast'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#   0.9842061512884456],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'California', 'Central Coast', 'Pinot Noir'}),
#   0.988313856427379],
#  [frozenset({'California'}),
#   frozenset({'@mattkettmann', 'California', 'Central Coast', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'Central Coast'}),
#   frozenset({'@mattkettmann', 'California', 'Central Coast', 'Pinot Noir'}),
#   0.9842061512884456],
#  [frozenset({'California'}),
#   frozenset({'California', 'Central Coast', 'Pinot Noir', 'US'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Pinot Noir', 'US'}),
#   0.988313856427379],
#  [frozenset({'Central Coast'}),
#   frozenset({'@mattkettmann', 'Central Coast', 'Pinot Noir', 'US'}),
#   0.9842061512884456],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'California', 'Matt Kettmann', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@mattkettmann', 'California', 'Matt Kettmann', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'@mattkettmann', 'California', 'Matt Kettmann', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'California', 'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'California', 'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#   0.988313856427379],
#  [frozenset({'Central Coast'}),
#   frozenset({'California', 'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#   0.9842061512884456],
#  [frozenset({'California'}),
#   frozenset({'California', 'Matt Kettmann', 'Pinot Noir', 'US'}),
#   1.0],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann', 'Matt Kettmann', 'Pinot Noir', 'US'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'@mattkettmann', 'Matt Kettmann', 'Pinot Noir', 'US'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'Central Coast', 'Matt Kettmann', 'Pinot Noir', 'US'}),
#   0.988313856427379],
#  [frozenset({'Central Coast'}),
#   frozenset({'Central Coast', 'Matt Kettmann', 'Pinot Noir', 'US'}),
#   0.9842061512884456],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Central Coast', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Central Coast', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'Central Coast'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Central Coast', 'Matt Kettmann'}),
#   0.9675297986025484],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Central Coast', 'US'}),
#   0.9569105691056911],
#  [frozenset({'Central Coast'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Central Coast', 'US'}),
#   0.9675297986025484],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Matt Kettmann', 'US'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'Matt Kettmann', 'US'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'(90, 95]', 'Central Coast', 'Matt Kettmann', 'US'}),
#   0.9569105691056911],
#  [frozenset({'Central Coast'}),
#   frozenset({'(90, 95]', 'Central Coast', 'Matt Kettmann', 'US'}),
#   0.9675297986025484],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'California', 'Central Coast'}),
#   0.9569105691056911],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'California', 'Central Coast'}),
#   1.0],
#  [frozenset({'Central Coast'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'California', 'Central Coast'}),
#   0.9675297986025484],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'California', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'California', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'(90, 95]', '@mattkettmann', 'California', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]', 'California', 'Central Coast', 'Matt Kettmann'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
# ...
#   frozenset({'@vboone',
#              'Cabernet Sauvignon',
#              'California',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone',
#              'Cabernet Sauvignon',
#              'California',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@vboone',
#              'Cabernet Sauvignon',
#              'California',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   0.9824654622741765],
#  [frozenset({'Oregon'}),
#   frozenset({'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Willamette Valley'}),
#   frozenset({'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   0.9305485656768999],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   0.9296128707893415],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(85, 90]', 'Oregon', 'Paul Gregutt', 'US', 'Willamette Valley'}),
#   0.9828869047619048],
#  [frozenset({'Oregon'}),
#   frozenset({'(85, 90]', 'Oregon', 'Paul Gregutt', 'US', 'Willamette Valley'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Paul Gregutt',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Paul Gregutt',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   0.9824654622741765],
#  [frozenset({'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   0.9305485656768999],
#  [frozenset({'Oregon'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Oregon',
#              'US',
#              'Willamette Valley'}),
#   0.9828869047619048],
#  [frozenset({'Oregon'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Oregon',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'Willamette Valley'}),
#   0.9305485656768999],
#  [frozenset({'Oregon'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Oregon'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Oregon'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'Pinot Noir', 'US'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'Pinot Noir', 'US'}),
#   1.0],
#  [frozenset({'Oregon'}),
#   frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'Pinot Noir', 'US'}),
#   0.9989944695827049],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'US'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Columbia Valley',
#              'Paul Gregutt',
#              'US',
#              'Washington'}),
#   0.9379407616361071],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone',
#              'California',
#              'Russian River Valley',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'Sonoma'}),
#   frozenset({'@vboone',
#              'California',
#              'Russian River Valley',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@vboone',
#              'California',
#              'Russian River Valley',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(90, 95]',
#              '@vboone',
#              'California',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]',
#              '@vboone',
#              'California',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'Pinot Noir',
#              'US'}),
#   1.0],
#  [frozenset({'Central Coast'}),
#   frozenset({'@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'Pinot Noir',
#              'US'}),
#   0.9842061512884456],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'Pinot Noir',
#              'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'Pinot Noir',
#              'US'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'(90, 95]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   1.0],
#  [frozenset({'Central Coast'}),
#   frozenset({'(90, 95]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   0.9675297986025484],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'(90, 95]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(90, 95]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'(85, 90]',
#              '@wawinereport',
#              'Columbia Valley',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'@wawinereport'}),
#   frozenset({'(85, 90]',
#              '@wawinereport',
#              'Columbia Valley',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'(85, 90]',
#              '@wawinereport',
#              'Columbia Valley',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   0.9391089108910892],
#  [frozenset({'Sean P. Sullivan'}),
#   frozenset({'(85, 90]',
#              '@wawinereport',
#              'Columbia Valley',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'Washington'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'@wawinereport'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'Columbia Valley'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'Sean P. Sullivan'}),
#   frozenset({'@wawinereport',
#              'Columbia Valley',
#              'Columbia Valley (WA)',
#              'Sean P. Sullivan',
#              'US',
#              'Washington'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone',
#              'California',
#              'Pinot Noir',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone',
#              'California',
#              'Pinot Noir',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'Sonoma'}),
#   frozenset({'@vboone',
#              'California',
#              'Pinot Noir',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   0.8631123919308357],
#  [frozenset({'California'}),
#   frozenset({'@vboone',
#              'California',
#              'Pinot Noir',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'(85, 90]',
#              '@vboone',
#              'California',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'(85, 90]',
#              '@vboone',
#              'California',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]',
#              '@vboone',
#              'California',
#              'Sonoma',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'Matt Kettmann'}),
#   frozenset({'(85, 90]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   1.0],
#  [frozenset({'Central Coast'}),
#   frozenset({'(85, 90]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   0.9353991596638656],
#  [frozenset({'@mattkettmann'}),
#   frozenset({'(85, 90]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   1.0],
#  [frozenset({'California'}),
#   frozenset({'(85, 90]',
#              '@mattkettmann',
#              'California',
#              'Central Coast',
#              'Matt Kettmann',
#              'US'}),
#   1.0],
#  [frozenset({'@vboone'}),
#   frozenset({'@vboone',
#              'California',
#              'Napa',
#              'Napa Valley',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'Virginie Boone'}),
#   frozenset({'@vboone',
#              'California',
#              'Napa',
#              'Napa Valley',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'Napa'}),
#   frozenset({'@vboone',
#              'California',
#              'Napa',
#              'Napa Valley',
#              'US',
#              'Virginie Boone'}),
#   0.9991119005328597],
#  [frozenset({'California'}),
#   frozenset({'@vboone',
#              'California',
#              'Napa',
#              'Napa Valley',
#              'US',
#              'Virginie Boone'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Oregon'}),
#   frozenset({'(85, 90]',
#              '@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'@paulgwine\xa0'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Paul Gregutt'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   1.0],
#  [frozenset({'Willamette Valley'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   0.9305485656768999],
#  [frozenset({'Oregon'}),
#   frozenset({'@paulgwine\xa0',
#              'Oregon',
#              'Paul Gregutt',
#              'Pinot Noir',
#              'US',
#              'Willamette Valley'}),
#   1.0]]

# %%
#全自信度检验
def all_confidence(conList,suppData):
    result = []
    for item in confList:
        score = suppData.get(item[1])/max(suppData.get(item[0]),suppData.get(item[1]-item[0]))
        result.append(['全自信度为:{0}'.format(score),item])
    return result

all_confidence(confList,suppData)  #查看全自信度
# Out:
# [['全自信度为:0.07830437307365883',
#   [frozenset({'US'}), frozenset({'(80, 85]', 'US'}), 1.0]],
#  ['全自信度为:0.10751775584044311',
#   [frozenset({'US'}), frozenset({'Chardonnay', 'US'}), 1.0]],
#  ['全自信度为:0.08554071559387144',
#   [frozenset({'US'}), frozenset({'@gordone_cellars', 'US'}), 1.0]],
#  ['全自信度为:0.14844961240310076',
#   [frozenset({'California'}),
#    frozenset({'@gordone_cellars', 'California'}),
#    1.0]],
#  ['全自信度为:0.08554071559387144',
#   [frozenset({'US'}), frozenset({'Jim Gordon', 'US'}), 1.0]],
#  ['全自信度为:0.14844961240310076',
#   [frozenset({'California'}), frozenset({'California', 'Jim Gordon'}), 1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'Jim Gordon'}),
#    frozenset({'@gordone_cellars', 'Jim Gordon'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'@gordone_cellars'}),
#    frozenset({'@gordone_cellars', 'Jim Gordon'}),
#    1.0]],
#  ['全自信度为:0.058114084066645824',
#   [frozenset({'US'}), frozenset({'Russian River Valley', 'US'}), 1.0]],
#  ['全自信度为:0.19775770787916536',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Russian River Valley'}),
#    0.9761721752498077]],
#  ['全自信度为:0.10085271317829457',
#   [frozenset({'California'}),
#    frozenset({'California', 'Russian River Valley'}),
#    1.0]],
#  ['全自信度为:0.19775770787916536',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'Russian River Valley', 'Virginie Boone'}),
#    0.9761721752498077]],
#  ['全自信度为:0.38777943368107304',
#   [frozenset({'Sonoma'}), frozenset({'Russian River Valley', 'Sonoma'}), 1.0]],
#  ['全自信度为:0.07513288962344218',
#   [frozenset({'US'}), frozenset({'Syrah', 'US'}), 1.0]],
#  ['全自信度为:0.3855362487157725',
#   [frozenset({'US'}), frozenset({'(90, 95]', 'US'}), 1.0]],
#  ['全自信度为:0.08067181846607406',
#   [frozenset({'US'}), frozenset({'Red Blend', 'US'}), 1.0]],
#  ['全自信度为:0.09099030687452539',
#   [frozenset({'US'}), frozenset({'(50, 60]', 'US'}), 1.0]],
#  ['全自信度为:0.1944878724259615',
#   [frozenset({'US'}), frozenset({'(30, 40]', 'US'}), 1.0]],
#  ['全自信度为:0.14995309777996157',
#   [frozenset({'US'}), frozenset({'@wawinereport', 'US'}), 1.0]],
#  ['全自信度为:0.2471076964309644',
#   [frozenset({'US'}), frozenset({'Columbia Valley', 'US'}), 1.0]],
#  ['全自信度为:0.552060737527115',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'@wawinereport', 'Columbia Valley'}),
#    0.9097408400357463]],
#  ['全自信度为:0.11113592710054943',
#   [frozenset({'US'}), frozenset({'Columbia Valley (WA)', 'US'}), 1.0]],
#  ['全自信度为:0.4497469269703543',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'Columbia Valley', 'Columbia Valley (WA)'}),
#    1.0]],
#  ['全自信度为:0.14995309777996157',
#   [frozenset({'US'}), frozenset({'Sean P. Sullivan', 'US'}), 1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'Sean P. Sullivan'}),
#    frozenset({'@wawinereport', 'Sean P. Sullivan'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'@wawinereport'}),
#    frozenset({'@wawinereport', 'Sean P. Sullivan'}),
#    1.0]],
#  ['全自信度为:0.552060737527115',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'Columbia Valley', 'Sean P. Sullivan'}),
#    0.9097408400357463]],
#  ['全自信度为:0.261089024880511',
#   [frozenset({'US'}), frozenset({'US', 'Washington'}), 1.0]],
#  ['全自信度为:0.5532934131736527',
#   [frozenset({'Washington'}),
#    frozenset({'@wawinereport', 'Washington'}),
#    0.9633601429848079]],
#  ['全自信度为:0.9464499572284003',
#   [frozenset({'Washington'}),
#    frozenset({'Columbia Valley', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.9464499572284003',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'Columbia Valley', 'Washington'}),
#    0.9464499572284003]],
#  ['全自信度为:0.4256629597946963',
#   [frozenset({'Washington'}),
#    frozenset({'Columbia Valley (WA)', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.5532934131736527',
#   [frozenset({'Washington'}),
#    frozenset({'Sean P. Sullivan', 'Washington'}),
#    0.9633601429848079]],
#  ['全自信度为:0.16987537410104078',
#   [frozenset({'US'}), frozenset({'(40, 50]', 'US'}), 1.0]],
#  ['全自信度为:0.14986376021798364',
#   [frozenset({'US'}), frozenset({'Sonoma', 'US'}), 1.0]],
#  ['全自信度为:0.5031142946122703',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Sonoma'}),
#    0.9630402384500746]],
#  ['全自信度为:0.2600775193798449',
#   [frozenset({'California'}), frozenset({'California', 'Sonoma'}), 1.0]],
#  ['全自信度为:0.5031142946122703',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'Sonoma', 'Virginie Boone'}),
#    0.9630402384500746]],
#  ['全自信度为:0.2344217626300978',
#   [frozenset({'US'}), frozenset({'(20, 30]', 'US'}), 1.0]],
#  ['全自信度为:0.20007147004958234',
#   [frozenset({'US'}), frozenset({'@mattkettmann', 'US'}), 1.0]],
#  ['全自信度为:0.3472093023255814',
#   [frozenset({'California'}),
#    frozenset({'@mattkettmann', 'California'}),
#    1.0]],
#  ['全自信度为:0.20945191405726538',
#   [frozenset({'US'}), frozenset({'Central Coast', 'US'}), 1.0]],
#  ['全自信度为:0.36348837209302326',
#   [frozenset({'California'}),
#    frozenset({'California', 'Central Coast'}),
#    1.0]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'@mattkettmann', 'Central Coast'}),
#    0.909575602473875]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'Central Coast'}),
#    frozenset({'@mattkettmann', 'Central Coast'}),
#    0.952221478008484]],
#  ['全自信度为:0.20007147004958234',
#   [frozenset({'US'}), frozenset({'Matt Kettmann', 'US'}), 1.0]],
#  ['全自信度为:0.3472093023255814',
#   [frozenset({'California'}),
#    frozenset({'California', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'@mattkettmann', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'@mattkettmann', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'Central Coast', 'Matt Kettmann'}),
#    0.909575602473875]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'Central Coast'}),
#    frozenset({'Central Coast', 'Matt Kettmann'}),
#    0.952221478008484]],
#  ['全自信度为:0.1693393487291732',
#   [frozenset({'US'}), frozenset({'(0, 20]', 'US'}), 1.0]],
#  ['全自信度为:0.28686291151114485',
#   [frozenset({'US'}), frozenset({'@vboone', 'US'}), 1.0]],
#  ['全自信度为:0.10595434850582927',
#   [frozenset({'US'}), frozenset({'Cabernet Sauvignon', 'US'}), 1.0]],
#  ['全自信度为:0.5762272747576719',
#   [frozenset({'US'}), frozenset({'California', 'US'}), 1.0]],
#  ['全自信度为:0.49782945736434103',
#   [frozenset({'California'}), frozenset({'@vboone', 'California'}), 1.0]],
#  ['全自信度为:0.08621074730870594',
#   [frozenset({'US'}), frozenset({'Napa', 'US'}), 1.0]],
#  ['全自信度为:0.2952351292432264',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Napa'}),
#    0.9823834196891194]],
#  ['全自信度为:0.14961240310077517',
#   [frozenset({'California'}), frozenset({'California', 'Napa'}), 1.0]],
#  ['全自信度为:0.051503104480278734',
#   [frozenset({'US'}), frozenset({'Napa Valley', 'US'}), 1.0]],
#  ['全自信度为:0.17533478667081906',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Napa Valley'}),
#    0.9765828274067649]],
#  ['全自信度为:0.08937984496124031',
#   [frozenset({'California'}), frozenset({'California', 'Napa Valley'}), 1.0]],
#  ['全自信度为:0.5968911917098446',
#   [frozenset({'Napa'}),
#    frozenset({'Napa', 'Napa Valley'}),
#    0.9991326973113617]],
#  ['全自信度为:0.28686291151114485',
#   [frozenset({'US'}), frozenset({'US', 'Virginie Boone'}), 1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'@vboone'}), frozenset({'@vboone', 'Virginie Boone'}), 1.0]],
#  ['全自信度为:0.49782945736434103',
#   [frozenset({'California'}),
#    frozenset({'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.2952351292432264',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'Napa', 'Virginie Boone'}),
#    0.9823834196891194]],
#  ['全自信度为:0.17533478667081906',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'Napa Valley', 'Virginie Boone'}),
#    0.9765828274067649]],
#  ['全自信度为:0.5530138587410252',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Oregon'}),
#    0.9492691315563198]],
#  ['全自信度为:1.0',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'@paulgwine\xa0', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.5530138587410252',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'Oregon', 'Paul Gregutt'}),
#    0.9492691315563198]],
#  ['全自信度为:0.14088533523920133',
#   [frozenset({'US'}), frozenset({'(60, 2100]', 'US'}), 1.0]],
#  ['全自信度为:0.527582972260687',
#   [frozenset({'US'}), frozenset({'(85, 90]', 'US'}), 1.0]],
#  ['全自信度为:0.2675213293429222',
#   [frozenset({'US'}), frozenset({'@paulgwine\xa0', 'US'}), 1.0]],
#  ['全自信度为:0.1558493768705052',
#   [frozenset({'US'}), frozenset({'Oregon', 'US'}), 1.0]],
#  ['全自信度为:0.2675213293429222',
#   [frozenset({'US'}), frozenset({'Paul Gregutt', 'US'}), 1.0]],
#  ['全自信度为:0.21472283021396346',
#   [frozenset({'US'}), frozenset({'Pinot Noir', 'US'}), 1.0]],
#  ['全自信度为:0.4287861078644181',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Willamette Valley'}),
#    0.9865539761813292]],
#  ['全自信度为:0.7460590427056464',
#   [frozenset({'Oregon'}), frozenset({'Oregon', 'Willamette Valley'}), 1.0]],
#  ['全自信度为:0.4287861078644181',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'Paul Gregutt', 'Willamette Valley'}),
#    0.9865539761813292]],
#  ['全自信度为:0.11627283691428061',
#   [frozenset({'US'}), frozenset({'US', 'Willamette Valley'}), 1.0]],
#  ['全自信度为:0.05413856255862778',
#   [frozenset({'US'}), frozenset({'(30, 40]', 'US', 'Washington'}), 1.0]],
#  ['全自信度为:0.05190512350917943',
#   [frozenset({'US'}), frozenset({'(30, 40]', 'Columbia Valley', 'US'}), 1.0]],
#  ['全自信度为:0.0838433019162907',
#   [frozenset({'US'}), frozenset({'(90, 95]', 'US', 'Washington'}), 1.0]],
#  ['全自信度为:0.08093983115200787',
#   [frozenset({'US'}), frozenset({'(90, 95]', 'Columbia Valley', 'US'}), 1.0]],
#  ['全自信度为:0.31000855431993163',
#   [frozenset({'Washington'}),
#    frozenset({'(90, 95]', 'Columbia Valley', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.3275488069414317',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'(90, 95]', 'Columbia Valley', 'Washington'}),
#    0.9653702717101759]],
#  ['全自信度为:0.19880239520958085',
#   [frozenset({'Washington'}),
#    frozenset({'(30, 40]', 'Columbia Valley', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.21005061460592914',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'(30, 40]', 'Columbia Valley', 'Washington'}),
#    0.9587458745874586]],
#  ['全自信度为:0.05462991914950641',
#   [frozenset({'US'}), frozenset({'(0, 20]', 'Paul Gregutt', 'US'}), 1.0]],
#  ['全自信度为:0.11649618081922544',
#   [frozenset({'US'}), frozenset({'Paul Gregutt', 'US', 'Washington'}), 1.0]],
#  ['全自信度为:0.06356367534729977',
#   [frozenset({'US'}), frozenset({'(0, 20]', 'US', 'Washington'}), 1.0]],
#  ['全自信度为:0.05722070844686648',
#   [frozenset({'US'}),
#    frozenset({'Columbia Valley (WA)', 'Paul Gregutt', 'US'}),
#    1.0]],
#  ['全自信度为:0.11055523294769286',
#   [frozenset({'US'}),
#    frozenset({'Columbia Valley', 'Paul Gregutt', 'US'}),
#    1.0]],
#  ['全自信度为:0.05780140259972305',
#   [frozenset({'US'}), frozenset({'(0, 20]', 'Columbia Valley', 'US'}), 1.0]],
#  ['全自信度为:0.2213857998289136',
#   [frozenset({'Washington'}),
#    frozenset({'(0, 20]', 'Columbia Valley', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.2339117859725235',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'(0, 20]', 'Columbia Valley', 'Washington'}),
#    0.9093464511595221]],
#  ['全自信度为:0.21916167664670658',
#   [frozenset({'Washington'}),
#    frozenset({'Columbia Valley (WA)', 'Paul Gregutt', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.4234388366124893',
#   [frozenset({'Washington'}),
#    frozenset({'Columbia Valley', 'Paul Gregutt', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.44739696312364424',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'Columbia Valley', 'Paul Gregutt', 'Washington'}),
#    0.9490030674846626]],
#  ['全自信度为:0.11649618081922544',
#   [frozenset({'US'}), frozenset({'@paulgwine\xa0', 'US', 'Washington'}), 1.0]],
#  ['全自信度为:0.4354650192018701',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.4354650192018701',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.05722070844686648',
#   [frozenset({'US'}),
#    frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'US'}),
#    1.0]],
#  ['全自信度为:0.21389213558190015',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.21389213558190015',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.21916167664670658',
#   [frozenset({'Washington'}),
#    frozenset({'@paulgwine\xa0', 'Columbia Valley (WA)', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.23156182212581344',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.11055523294769286',
#   [frozenset({'US'}),
#    frozenset({'@paulgwine\xa0', 'Columbia Valley', 'US'}),
#    1.0]],
#  ['全自信度为:0.41325763900484225',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.41325763900484225',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.4234388366124893',
#   [frozenset({'Washington'}),
#    frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.44739696312364424',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Washington'}),
#    0.9490030674846626]],
#  ['全自信度为:0.23156182212581344',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'@paulgwine\xa0', 'Columbia Valley', 'Columbia Valley (WA)'}),
#    1.0]],
#  ['全自信度为:0.05462991914950641',
#   [frozenset({'US'}), frozenset({'(0, 20]', '@paulgwine\xa0', 'US'}), 1.0]],
#  ['全自信度为:0.20420771414259478',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'(0, 20]', '@paulgwine\xa0', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.20420771414259478',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'(0, 20]', '@paulgwine\xa0', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.09661857327913521',
#   [frozenset({'US'}), frozenset({'(90, 95]', 'Paul Gregutt', 'US'}), 1.0]],
#  ['全自信度为:0.05842676553356859',
#   [frozenset({'US'}), frozenset({'(90, 95]', 'Oregon', 'US'}), 1.0]],
#  ['全自信度为:0.21188846218066457',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'(90, 95]', 'Oregon', 'Paul Gregutt'}),
#    0.970183486238532]],
#  ['全自信度为:0.09661857327913521',
#   [frozenset({'US'}), frozenset({'(90, 95]', '@paulgwine\xa0', 'US'}), 1.0]],
#  ['全自信度为:0.3611621305727167',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'(90, 95]', '@paulgwine\xa0', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.3611621305727167',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'(90, 95]', '@paulgwine\xa0', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.21188846218066457',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'(90, 95]', '@paulgwine\xa0', 'Oregon'}),
#    0.970183486238532]],
#  ['全自信度为:0.050386384955554565',
#   [frozenset({'US'}), frozenset({'(30, 40]', 'Paul Gregutt', 'US'}), 1.0]],
#  ['全自信度为:0.050386384955554565',
#   [frozenset({'US'}), frozenset({'(30, 40]', '@paulgwine\xa0', 'US'}), 1.0]],
#  ['全自信度为:0.18834529971614627',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'(30, 40]', '@paulgwine\xa0', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.18834529971614627',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'(30, 40]', '@paulgwine\xa0', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.05212846741412427',
#   [frozenset({'US'}), frozenset({'(85, 90]', 'Chardonnay', 'US'}), 1.0]],
#  ['全自信度为:0.07522222718542011',
#   [frozenset({'US'}), frozenset({'California', 'Chardonnay', 'US'}), 1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'Jim Gordon'}),
#    frozenset({'@gordone_cellars', 'California', 'Jim Gordon'}),
#    1.0]],
#  ['全自信度为:0.14844961240310076',
#   [frozenset({'California'}),
#    frozenset({'@gordone_cellars', 'California', 'Jim Gordon'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'@gordone_cellars'}),
#    frozenset({'@gordone_cellars', 'California', 'Jim Gordon'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'Jim Gordon'}),
#    frozenset({'@gordone_cellars', 'Jim Gordon', 'US'}),
#    1.0]],
#  ['全自信度为:0.08554071559387144',
#   [frozenset({'US'}),
#    frozenset({'@gordone_cellars', 'Jim Gordon', 'US'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'@gordone_cellars'}),
#    frozenset({'@gordone_cellars', 'Jim Gordon', 'US'}),
#    1.0]],
#  ['全自信度为:0.08554071559387144',
#   [frozenset({'US'}), frozenset({'California', 'Jim Gordon', 'US'}), 1.0]],
#  ['全自信度为:0.14844961240310076',
#   [frozenset({'California'}),
#    frozenset({'California', 'Jim Gordon', 'US'}),
#    1.0]],
#  ['全自信度为:0.6182767624020887',
#   [frozenset({'Jim Gordon'}),
#    frozenset({'(85, 90]', '@gordone_cellars', 'Jim Gordon'}),
#    1.0]],
#  ['全自信度为:0.6182767624020887',
#   [frozenset({'@gordone_cellars'}),
#    frozenset({'(85, 90]', '@gordone_cellars', 'Jim Gordon'}),
#    1.0]],
#  ['全自信度为:0.0917829457364341',
#   [frozenset({'California'}),
#    frozenset({'(85, 90]', 'California', 'Jim Gordon'}),
#    1.0]],
#  ['全自信度为:0.052887836690936704',
#   [frozenset({'US'}), frozenset({'(85, 90]', 'Jim Gordon', 'US'}), 1.0]],
#  ['全自信度为:0.0917829457364341',
#   [frozenset({'California'}),
#    frozenset({'(85, 90]', '@gordone_cellars', 'California'}),
#    1.0]],
#  ['全自信度为:0.052887836690936704',
#   [frozenset({'US'}), frozenset({'(85, 90]', '@gordone_cellars', 'US'}), 1.0]],
#  ['全自信度为:0.08554071559387144',
#   [frozenset({'US'}),
#    frozenset({'@gordone_cellars', 'California', 'US'}),
#    1.0]],
#  ['全自信度为:0.14844961240310076',
#   [frozenset({'California'}),
#    frozenset({'@gordone_cellars', 'California', 'US'}),
#    1.0]],
#  ['全自信度为:0.05226247375709117',
#   [frozenset({'US'}), frozenset({'(40, 50]', 'US', 'Virginie Boone'}), 1.0]],
#  ['全自信度为:0.05226247375709117',
#   [frozenset({'US'}), frozenset({'(40, 50]', '@vboone', 'US'}), 1.0]],
#  ['全自信度为:0.06575244561575914',
#   [frozenset({'US'}), frozenset({'(90, 95]', 'Sonoma', 'US'}), 1.0]],
#  ['全自信度为:0.09069767441860466',
#   [frozenset({'California'}),
#    frozenset({'(40, 50]', '@vboone', 'California'}),
#    1.0]],
#  ['全自信度为:0.37853949329359166',
#   [frozenset({'Sonoma'}),
#    frozenset({'Russian River Valley', 'Sonoma', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.19775770787916536',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'Russian River Valley', 'Sonoma', 'Virginie Boone'}),
#    0.9761721752498077]],
#  ['全自信度为:0.38777943368107304',
#   [frozenset({'Sonoma'}),
#    frozenset({'California', 'Russian River Valley', 'Sonoma'}),
#    1.0]],
#  ['全自信度为:0.10085271317829457',
#   [frozenset({'California'}),
#    frozenset({'California', 'Russian River Valley', 'Sonoma'}),
#    1.0]],
#  ['全自信度为:0.37853949329359166',
#   [frozenset({'Sonoma'}),
#    frozenset({'@vboone', 'Russian River Valley', 'Sonoma'}),
#    1.0]],
#  ['全自信度为:0.19775770787916536',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Russian River Valley', 'Sonoma'}),
#    0.9761721752498077]],
#  ['全自信度为:0.19775770787916536',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'California', 'Russian River Valley', 'Virginie Boone'}),
#    0.9761721752498077]],
#  ['全自信度为:0.09844961240310077',
#   [frozenset({'California'}),
#    frozenset({'California', 'Russian River Valley', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.19775770787916536',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'Russian River Valley', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.19775770787916536',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Russian River Valley', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.09844961240310077',
#   [frozenset({'California'}),
#    frozenset({'@vboone', 'California', 'Russian River Valley'}),
#    1.0]],
#  ['全自信度为:0.19775770787916536',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'California', 'Russian River Valley'}),
#    0.9761721752498077]],
#  ['全自信度为:0.05672935185598785',
#   [frozenset({'US'}),
#    frozenset({'Russian River Valley', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.19775770787916536',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'Russian River Valley', 'US', 'Virginie Boone'}),
#    0.9761721752498077]],
#  ['全自信度为:0.058114084066645824',
#   [frozenset({'US'}),
#    frozenset({'California', 'Russian River Valley', 'US'}),
#    1.0]],
#  ['全自信度为:0.10085271317829457',
#   [frozenset({'California'}),
#    frozenset({'California', 'Russian River Valley', 'US'}),
#    1.0]],
#  ['全自信度为:0.05672935185598785',
#   [frozenset({'US'}),
#    frozenset({'@vboone', 'Russian River Valley', 'US'}),
#    1.0]],
#  ['全自信度为:0.19775770787916536',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Russian River Valley', 'US'}),
#    0.9761721752498077]],
#  ['全自信度为:0.058114084066645824',
#   [frozenset({'US'}),
#    frozenset({'Russian River Valley', 'Sonoma', 'US'}),
#    1.0]],
#  ['全自信度为:0.38777943368107304',
#   [frozenset({'Sonoma'}),
#    frozenset({'Russian River Valley', 'Sonoma', 'US'}),
#    1.0]],
#  ['全自信度为:0.21846776705076298',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'(90, 95]', 'Sonoma', 'Virginie Boone'}),
#    0.953125]],
#  ['全自信度为:0.11410852713178295',
#   [frozenset({'California'}),
#    frozenset({'(90, 95]', 'California', 'Sonoma'}),
#    1.0]],
#  ['全自信度为:0.21846776705076298',
#   [frozenset({'@vboone'}),
#    frozenset({'(90, 95]', '@vboone', 'Sonoma'}),
#    0.953125]],
#  ['全自信度为:0.09069767441860466',
#   [frozenset({'California'}),
#    frozenset({'(40, 50]', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.1821862348178138',
#   [frozenset({'@vboone'}),
#    frozenset({'(40, 50]', '@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.1821862348178138',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'(40, 50]', '@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.10492696654308303',
#   [frozenset({'US'}), frozenset({'(40, 50]', 'California', 'US'}), 1.0]],
#  ['全自信度为:0.09349175860990754',
#   [frozenset({'US'}), frozenset({'(40, 50]', '(90, 95]', 'US'}), 1.0]],
#  ['全自信度为:0.05650600795104302',
#   [frozenset({'US'}), frozenset({'(50, 60]', '(90, 95]', 'US'}), 1.0]],
#  ['全自信度为:0.05119042301335597',
#   [frozenset({'US'}), frozenset({'(20, 30]', '(90, 95]', 'US'}), 1.0]],
#  ['全自信度为:0.07406083887970698',
#   [frozenset({'US'}), frozenset({'(30, 40]', '(90, 95]', 'US'}), 1.0]],
#  ['全自信度为:0.18860465116279068',
#   [frozenset({'California'}),
#    frozenset({'(90, 95]', 'California', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:0.19069767441860466',
#   [frozenset({'California'}),
#    frozenset({'(90, 95]', 'California', 'Central Coast'}),
#    1.0]],
#  ['全自信度为:0.18860465116279068',
#   [frozenset({'California'}),
#    frozenset({'(90, 95]', '@mattkettmann', 'California'}),
#    1.0]],
#  ['全自信度为:0.10867914414615625',
#   [frozenset({'US'}), frozenset({'(90, 95]', 'Matt Kettmann', 'US'}), 1.0]],
#  ['全自信度为:0.10988520123285836',
#   [frozenset({'US'}), frozenset({'(90, 95]', 'Central Coast', 'US'}), 1.0]],
#  ['全自信度为:0.10867914414615625',
#   [frozenset({'US'}), frozenset({'(90, 95]', '@mattkettmann', 'US'}), 1.0]],
#  ['全自信度为:0.5255637419066757',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'(90, 95]', 'Central Coast', 'Matt Kettmann'}),
#    0.9569105691056911]],
#  ['全自信度为:0.5020260183407976',
#   [frozenset({'Central Coast'}),
#    frozenset({'(90, 95]', 'Central Coast', 'Matt Kettmann'}),
#    0.9675297986025484]],
#  ['全自信度为:0.5432016075016745',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'(90, 95]', '@mattkettmann', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:0.5432016075016745',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'(90, 95]', '@mattkettmann', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:0.5255637419066757',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'(90, 95]', '@mattkettmann', 'Central Coast'}),
#    0.9569105691056911]],
#  ['全自信度为:0.5020260183407976',
#   [frozenset({'Central Coast'}),
#    frozenset({'(90, 95]', '@mattkettmann', 'Central Coast'}),
#    0.9675297986025484]],
#  ['全自信度为:0.11189529637736186',
#   [frozenset({'US'}), frozenset({'(90, 95]', 'Pinot Noir', 'US'}), 1.0]],
#  ['全自信度为:0.05373654352972707',
#   [frozenset({'US'}), frozenset({'Matt Kettmann', 'Pinot Noir', 'US'}), 1.0]],
#  ['全自信度为:0.09325581395348836',
#   [frozenset({'California'}),
#    frozenset({'California', 'Matt Kettmann', 'Pinot Noir'}),
#    1.0]],
#  ['全自信度为:0.05351319962478224',
#   [frozenset({'US'}), frozenset({'Central Coast', 'Pinot Noir', 'US'}), 1.0]],
#  ['全自信度为:0.09286821705426355',
#   [frozenset({'California'}),
#    frozenset({'California', 'Central Coast', 'Pinot Noir'}),
#    1.0]],
#  ['全自信度为:0.2643447198035276',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#    0.988313856427379]],
#  ['全自信度为:0.25250586478993386',
#   [frozenset({'Central Coast'}),
#    frozenset({'Central Coast', 'Matt Kettmann', 'Pinot Noir'}),
#    0.9842061512884456]],
#  ['全自信度为:0.05373654352972707',
#   [frozenset({'US'}), frozenset({'@mattkettmann', 'Pinot Noir', 'US'}), 1.0]],
#  ['全自信度为:0.09325581395348836',
#   [frozenset({'California'}),
#    frozenset({'@mattkettmann', 'California', 'Pinot Noir'}),
#    1.0]],
#  ['全自信度为:0.26858673811118555',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'@mattkettmann', 'Matt Kettmann', 'Pinot Noir'}),
#    1.0]],
#  ['全自信度为:0.26858673811118555',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'@mattkettmann', 'Matt Kettmann', 'Pinot Noir'}),
#    1.0]],
#  ['全自信度为:0.2643447198035276',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'@mattkettmann', 'Central Coast', 'Pinot Noir'}),
#    0.988313856427379]],
#  ['全自信度为:0.25250586478993386',
#   [frozenset({'Central Coast'}),
#    frozenset({'@mattkettmann', 'Central Coast', 'Pinot Noir'}),
#    0.9842061512884456]],
#  ['全自信度为:0.19170542635658916',
#   [frozenset({'California'}),
#    frozenset({'(90, 95]', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.3850825288072252',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'(90, 95]', '@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.3850825288072252',
#   [frozenset({'@vboone'}),
#    frozenset({'(90, 95]', '@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.19170542635658916',
#   [frozenset({'California'}),
#    frozenset({'(90, 95]', '@vboone', 'California'}),
#    1.0]],
#  ['全自信度为:0.0947424844775986',
#   [frozenset({'US'}), frozenset({'(60, 2100]', '(90, 95]', 'US'}), 1.0]],
#  ['全自信度为:0.11046589538571493',
#   [frozenset({'US'}), frozenset({'(90, 95]', 'US', 'Virginie Boone'}), 1.0]],
#  ['全自信度为:0.24326618126591326',
#   [frozenset({'US'}), frozenset({'(90, 95]', 'California', 'US'}), 1.0]],
#  ['全自信度为:0.11046589538571493',
#   [frozenset({'US'}), frozenset({'(90, 95]', '@vboone', 'US'}), 1.0]],
#  ['全自信度为:0.0512797605753339',
#   [frozenset({'US'}), frozenset({'(85, 90]', 'Red Blend', 'US'}), 1.0]],
#  ['全自信度为:0.05302184303390361',
#   [frozenset({'US'}), frozenset({'(20, 30]', 'US', 'Virginie Boone'}), 1.0]],
#  ['全自信度为:0.05302184303390361',
#   [frozenset({'US'}), frozenset({'(20, 30]', '@vboone', 'US'}), 1.0]],
#  ['全自信度为:0.09201550387596899',
#   [frozenset({'California'}),
#    frozenset({'(20, 30]', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.09201550387596899',
#   [frozenset({'California'}),
#    frozenset({'(20, 30]', '@vboone', 'California'}),
#    1.0]],
#  ['全自信度为:0.18483338523824355',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'(20, 30]', '@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.18483338523824355',
#   [frozenset({'@vboone'}),
#    frozenset({'(20, 30]', '@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.07115736811542413',
#   [frozenset({'US'}), frozenset({'(20, 30]', 'Paul Gregutt', 'US'}), 1.0]],
#  ['全自信度为:0.07115736811542413',
#   [frozenset({'US'}), frozenset({'(20, 30]', '@paulgwine\xa0', 'US'}), 1.0]],
#  ['全自信度为:0.2659876440140257',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'(20, 30]', '@paulgwine\xa0', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.2659876440140257',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'(20, 30]', '@paulgwine\xa0', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.05900745968642516',
#   [frozenset({'US'}), frozenset({'(50, 60]', 'California', 'US'}), 1.0]],
#  ['全自信度为:0.0875968992248062',
#   [frozenset({'California'}),
#    frozenset({'(30, 40]', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17595764559327312',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'(30, 40]', '@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17595764559327312',
#   [frozenset({'@vboone'}),
#    frozenset({'(30, 40]', '@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.0875968992248062',
#   [frozenset({'California'}),
#    frozenset({'(30, 40]', '@vboone', 'California'}),
#    1.0]],
#  ['全自信度为:0.10858980658417831',
#   [frozenset({'US'}), frozenset({'(30, 40]', '(85, 90]', 'US'}), 1.0]],
#  ['全自信度为:0.0504757225175325',
#   [frozenset({'US'}), frozenset({'(30, 40]', 'US', 'Virginie Boone'}), 1.0]],
#  ['全自信度为:0.10992987001384733',
#   [frozenset({'US'}), frozenset({'(30, 40]', 'California', 'US'}), 1.0]],
#  ['全自信度为:0.0504757225175325',
#   [frozenset({'US'}), frozenset({'(30, 40]', '@vboone', 'US'}), 1.0]],
#  ['全自信度为:0.20615911035072715',
#   [frozenset({'Washington'}),
#    frozenset({'Columbia Valley (WA)', 'Sean P. Sullivan', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.5224978614200172',
#   [frozenset({'Washington'}),
#    frozenset({'Columbia Valley', 'Sean P. Sullivan', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.552060737527115',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'Columbia Valley', 'Sean P. Sullivan', 'Washington'}),
#    0.9443413729128016]],
#  ['全自信度为:0.4256629597946963',
#   [frozenset({'Washington'}),
#    frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.4497469269703543',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.5532934131736527',
#   [frozenset({'Washington'}),
#    frozenset({'@wawinereport', 'Sean P. Sullivan', 'Washington'}),
#    0.9633601429848079]],
#  ['全自信度为:0.9633601429848079',
#   [frozenset({'Sean P. Sullivan'}),
#    frozenset({'@wawinereport', 'Sean P. Sullivan', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.9633601429848079',
#   [frozenset({'@wawinereport'}),
#    frozenset({'@wawinereport', 'Sean P. Sullivan', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.20615911035072715',
#   [frozenset({'Washington'}),
#    frozenset({'@wawinereport', 'Columbia Valley (WA)', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.552060737527115',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'@wawinereport', 'Columbia Valley', 'Washington'}),
#    0.9443413729128016]],
#  ['全自信度为:0.5224978614200172',
#   [frozenset({'Washington'}),
#    frozenset({'@wawinereport', 'Columbia Valley', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.2525235243798118',
#   [frozenset({'Washington'}),
#    frozenset({'(20, 30]', 'Columbia Valley', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.2668112798264642',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'(20, 30]', 'Columbia Valley', 'Washington'}),
#    0.9461538461538461]],
#  ['全自信度为:0.1535712690400679',
#   [frozenset({'US'}), frozenset({'(85, 90]', 'US', 'Washington'}), 1.0]],
#  ['全自信度为:0.06968329834278822',
#   [frozenset({'US'}), frozenset({'(20, 30]', 'US', 'Washington'}), 1.0]],
#  ['全自信度为:0.3455945252352438',
#   [frozenset({'Washington'}),
#    frozenset({'(85, 90]', 'Sean P. Sullivan', 'Washington'}),
#    0.9655831739961759]],
#  ['全自信度为:0.2668947818648417',
#   [frozenset({'Washington'}),
#    frozenset({'(85, 90]', 'Columbia Valley (WA)', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.5520958083832336',
#   [frozenset({'Washington'}),
#    frozenset({'(85, 90]', 'Columbia Valley', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.5833333333333334',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'(85, 90]', 'Columbia Valley', 'Washington'}),
#    0.9386271087841768]],
#  ['全自信度为:0.3455945252352438',
#   [frozenset({'Washington'}),
#    frozenset({'(85, 90]', '@wawinereport', 'Washington'}),
#    0.9655831739961759]],
#  ['全自信度为:0.217823571945047',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'Sean P. Sullivan'}),
#    1.0]],
#  ['全自信度为:0.3589514447423295',
#   [frozenset({'Sean P. Sullivan'}),
#    frozenset({'@wawinereport', 'Columbia Valley (WA)', 'Sean P. Sullivan'}),
#    1.0]],
#  ['全自信度为:0.3589514447423295',
#   [frozenset({'@wawinereport'}),
#    frozenset({'@wawinereport', 'Columbia Valley (WA)', 'Sean P. Sullivan'}),
#    1.0]],
#  ['全自信度为:0.552060737527115',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'@wawinereport', 'Columbia Valley', 'Sean P. Sullivan'}),
#    0.9097408400357463]],
#  ['全自信度为:0.9097408400357463',
#   [frozenset({'Sean P. Sullivan'}),
#    frozenset({'@wawinereport', 'Columbia Valley', 'Sean P. Sullivan'}),
#    1.0]],
#  ['全自信度为:0.9097408400357463',
#   [frozenset({'@wawinereport'}),
#    frozenset({'@wawinereport', 'Columbia Valley', 'Sean P. Sullivan'}),
#    1.0]],
#  ['全自信度为:0.09344708982891857',
#   [frozenset({'US'}), frozenset({'(85, 90]', 'Sean P. Sullivan', 'US'}), 1.0]],
#  ['全自信度为:0.14445883771831866',
#   [frozenset({'US'}),
#    frozenset({'Sean P. Sullivan', 'US', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.5532934131736527',
#   [frozenset({'Washington'}),
#    frozenset({'Sean P. Sullivan', 'US', 'Washington'}),
#    0.9633601429848079]],
#  ['全自信度为:0.3429139551699205',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'(85, 90]', 'Columbia Valley', 'Sean P. Sullivan'}),
#    0.9067877629063098]],
#  ['全自信度为:0.62317545427465',
#   [frozenset({'Sean P. Sullivan'}),
#    frozenset({'(85, 90]', '@wawinereport', 'Sean P. Sullivan'}),
#    1.0]],
#  ['全自信度为:0.62317545427465',
#   [frozenset({'@wawinereport'}),
#    frozenset({'(85, 90]', '@wawinereport', 'Sean P. Sullivan'}),
#    1.0]],
#  ['全自信度为:0.217823571945047',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'@wawinereport', 'Columbia Valley', 'Columbia Valley (WA)'}),
#    1.0]],
#  ['全自信度为:0.06968329834278822',
#   [frozenset({'US'}),
#    frozenset({'(85, 90]', 'Columbia Valley (WA)', 'US'}),
#    1.0]],
#  ['全自信度为:0.11113592710054943',
#   [frozenset({'US'}),
#    frozenset({'Columbia Valley (WA)', 'US', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.4256629597946963',
#   [frozenset({'Washington'}),
#    frozenset({'Columbia Valley (WA)', 'US', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.05382588109170501',
#   [frozenset({'US'}),
#    frozenset({'Columbia Valley (WA)', 'Sean P. Sullivan', 'US'}),
#    1.0]],
#  ['全自信度为:0.1441461562513959',
#   [frozenset({'US'}), frozenset({'(85, 90]', 'Columbia Valley', 'US'}), 1.0]],
#  ['全自信度为:0.06593112073971501',
#   [frozenset({'US'}), frozenset({'(20, 30]', 'Columbia Valley', 'US'}), 1.0]],
#  ['全自信度为:0.2471076964309644',
#   [frozenset({'US'}),
#    frozenset({'Columbia Valley', 'US', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.9464499572284003',
#   [frozenset({'Washington'}),
#    frozenset({'Columbia Valley', 'US', 'Washington'}),
#    1.0]],
#  ['全自信度为:0.9464499572284003',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'Columbia Valley', 'US', 'Washington'}),
#    0.9464499572284003]],
#  ['全自信度为:0.13641845714030465',
#   [frozenset({'US'}),
#    frozenset({'Columbia Valley', 'Sean P. Sullivan', 'US'}),
#    1.0]],
#  ['全自信度为:0.552060737527115',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'Columbia Valley', 'Sean P. Sullivan', 'US'}),
#    0.9097408400357463]],
#  ['全自信度为:0.11113592710054943',
#   [frozenset({'US'}),
#    frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'US'}),
#    1.0]],
#  ['全自信度为:0.4497469269703543',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'Columbia Valley', 'Columbia Valley (WA)', 'US'}),
#    1.0]],
#  ['全自信度为:0.28199566160520606',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'(85, 90]', 'Columbia Valley', 'Columbia Valley (WA)'}),
#    1.0]],
#  ['全自信度为:0.09344708982891857',
#   [frozenset({'US'}), frozenset({'(85, 90]', '@wawinereport', 'US'}), 1.0]],
#  ['全自信度为:0.14445883771831866',
#   [frozenset({'US'}), frozenset({'@wawinereport', 'US', 'Washington'}), 1.0]],
#  ['全自信度为:0.5532934131736527',
#   [frozenset({'Washington'}),
#    frozenset({'@wawinereport', 'US', 'Washington'}),
#    0.9633601429848079]],
#  ['全自信度为:0.14995309777996157',
#   [frozenset({'US'}),
#    frozenset({'@wawinereport', 'Sean P. Sullivan', 'US'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'Sean P. Sullivan'}),
#    frozenset({'@wawinereport', 'Sean P. Sullivan', 'US'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'@wawinereport'}),
#    frozenset({'@wawinereport', 'Sean P. Sullivan', 'US'}),
#    1.0]],
#  ['全自信度为:0.05382588109170501',
#   [frozenset({'US'}),
#    frozenset({'@wawinereport', 'Columbia Valley (WA)', 'US'}),
#    1.0]],
#  ['全自信度为:0.552060737527115',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'@wawinereport', 'Columbia Valley', 'US'}),
#    0.9097408400357463]],
#  ['全自信度为:0.13641845714030465',
#   [frozenset({'US'}),
#    frozenset({'@wawinereport', 'Columbia Valley', 'US'}),
#    1.0]],
#  ['全自信度为:0.3429139551699205',
#   [frozenset({'Columbia Valley'}),
#    frozenset({'(85, 90]', '@wawinereport', 'Columbia Valley'}),
#    0.9067877629063098]],
#  ['全自信度为:0.07111269933443516',
#   [frozenset({'US'}), frozenset({'(40, 50]', '(85, 90]', 'US'}), 1.0]],
#  ['全自信度为:0.05440657524456158',
#   [frozenset({'US'}), frozenset({'(40, 50]', 'Pinot Noir', 'US'}), 1.0]],
#  ['全自信度为:0.0717380622682807',
#   [frozenset({'US'}), frozenset({'(60, 2100]', 'US', 'Virginie Boone'}), 1.0]],
#  ['全自信度为:0.09925403135748426',
#   [frozenset({'US'}), frozenset({'(60, 2100]', 'California', 'US'}), 1.0]],
#  ['全自信度为:0.0717380622682807',
#   [frozenset({'US'}), frozenset({'(60, 2100]', '@vboone', 'US'}), 1.0]],
#  ['全自信度为:0.25046511627906975',
#   [frozenset({'California'}),
#    frozenset({'California', 'Sonoma', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.5031142946122703',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'California', 'Sonoma', 'Virginie Boone'}),
#    0.9630402384500746]],
#  ['全自信度为:0.5031142946122703',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'Sonoma', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.5031142946122703',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Sonoma', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.25046511627906975',
#   [frozenset({'California'}),
#    frozenset({'@vboone', 'California', 'Sonoma'}),
#    1.0]],
#  ['全自信度为:0.5031142946122703',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'California', 'Sonoma'}),
#    0.9630402384500746]],
#  ['全自信度为:0.07356948228882834',
#   [frozenset({'US'}), frozenset({'(85, 90]', 'Sonoma', 'US'}), 1.0]],
#  ['全自信度为:0.14432483137535176',
#   [frozenset({'US'}), frozenset({'Sonoma', 'US', 'Virginie Boone'}), 1.0]],
#  ['全自信度为:0.5031142946122703',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'Sonoma', 'US', 'Virginie Boone'}),
#    0.9630402384500746]],
#  ['全自信度为:0.14986376021798364',
#   [frozenset({'US'}), frozenset({'California', 'Sonoma', 'US'}), 1.0]],
#  ['全自信度为:0.2600775193798449',
#   [frozenset({'California'}), frozenset({'California', 'Sonoma', 'US'}), 1.0]],
#  ['全自信度为:0.14432483137535176',
#   [frozenset({'US'}), frozenset({'@vboone', 'Sonoma', 'US'}), 1.0]],
#  ['全自信度为:0.5031142946122703',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Sonoma', 'US'}),
#    0.9630402384500746]],
#  ['全自信度为:0.055835976236208514',
#   [frozenset({'US'}), frozenset({'Pinot Noir', 'Sonoma', 'US'}), 1.0]],
#  ['全自信度为:0.24883213952039865',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'(85, 90]', 'Sonoma', 'Virginie Boone'}),
#    0.9702489374620522]],
#  ['全自信度为:0.12767441860465117',
#   [frozenset({'California'}),
#    frozenset({'(85, 90]', 'California', 'Sonoma'}),
#    1.0]],
#  ['全自信度为:0.24883213952039865',
#   [frozenset({'@vboone'}),
#    frozenset({'(85, 90]', '@vboone', 'Sonoma'}),
#    0.9702489374620522]],
#  ['全自信度为:0.06200026801268593',
#   [frozenset({'US'}), frozenset({'Pinot Noir', 'US', 'Virginie Boone'}), 1.0]],
#  ['全自信度为:0.18654624727499222',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'Pinot Noir', 'Sonoma', 'Virginie Boone'}),
#    0.9583999999999999]],
#  ['全自信度为:0.3570789865871833',
#   [frozenset({'Sonoma'}),
#    frozenset({'Pinot Noir', 'Sonoma', 'Virginie Boone'}),
#    0.8631123919308357]],
#  ['全自信度为:0.12239245990976906',
#   [frozenset({'US'}), frozenset({'California', 'Pinot Noir', 'US'}), 1.0]],
#  ['全自信度为:0.09689922480620154',
#   [frozenset({'California'}),
#    frozenset({'California', 'Pinot Noir', 'Sonoma'}),
#    1.0]],
#  ['全自信度为:0.1075968992248062',
#   [frozenset({'California'}),
#    frozenset({'California', 'Pinot Noir', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.12449612403100774',
#   [frozenset({'California'}),
#    frozenset({'(60, 2100]', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.06200026801268593',
#   [frozenset({'US'}), frozenset({'@vboone', 'Pinot Noir', 'US'}), 1.0]],
#  ['全自信度为:0.3570789865871833',
#   [frozenset({'Sonoma'}),
#    frozenset({'@vboone', 'Pinot Noir', 'Sonoma'}),
#    0.8631123919308357]],
#  ['全自信度为:0.18654624727499222',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Pinot Noir', 'Sonoma'}),
#    0.9583999999999999]],
#  ['全自信度为:0.21613204609156028',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'Pinot Noir', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.21613204609156028',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Pinot Noir', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.1075968992248062',
#   [frozenset({'California'}),
#    frozenset({'@vboone', 'California', 'Pinot Noir'}),
#    1.0]],
#  ['全自信度为:0.25007785736530674',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'(60, 2100]', '@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.25007785736530674',
#   [frozenset({'@vboone'}),
#    frozenset({'(60, 2100]', '@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.12449612403100774',
#   [frozenset({'California'}),
#    frozenset({'(60, 2100]', '@vboone', 'California'}),
#    1.0]],
#  ['全自信度为:0.1475968992248062',
#   [frozenset({'California'}),
#    frozenset({'(85, 90]', 'California', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:0.0850493590029928',
#   [frozenset({'US'}), frozenset({'(85, 90]', 'Matt Kettmann', 'US'}), 1.0]],
#  ['全自信度为:0.20007147004958234',
#   [frozenset({'US'}), frozenset({'California', 'Matt Kettmann', 'US'}), 1.0]],
#  ['全自信度为:0.3472093023255814',
#   [frozenset({'California'}),
#    frozenset({'California', 'Matt Kettmann', 'US'}),
#    1.0]],
#  ['全自信度为:0.3976334003125698',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'(85, 90]', 'Central Coast', 'Matt Kettmann'}),
#    0.86962890625]],
#  ['全自信度为:0.3798251226274259',
#   [frozenset({'Central Coast'}),
#    frozenset({'(85, 90]', 'Central Coast', 'Matt Kettmann'}),
#    0.9353991596638656]],
#  ['全自信度为:0.952221478008484',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'@mattkettmann', 'Central Coast', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:0.952221478008484',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'@mattkettmann', 'Central Coast', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'Central Coast'}),
#    frozenset({'@mattkettmann', 'Central Coast', 'Matt Kettmann'}),
#    0.952221478008484]],
#  ['全自信度为:0.1587596899224806',
#   [frozenset({'California'}),
#    frozenset({'(85, 90]', 'California', 'Central Coast'}),
#    1.0]],
#  ['全自信度为:0.3306201550387597',
#   [frozenset({'California'}),
#    frozenset({'California', 'Central Coast', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'California', 'Central Coast', 'Matt Kettmann'}),
#    0.909575602473875]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'Central Coast'}),
#    frozenset({'California', 'Central Coast', 'Matt Kettmann'}),
#    0.952221478008484]],
#  ['全自信度为:0.09148166346540403',
#   [frozenset({'US'}), frozenset({'(85, 90]', 'Central Coast', 'US'}), 1.0]],
#  ['全自信度为:0.20945191405726538',
#   [frozenset({'US'}), frozenset({'California', 'Central Coast', 'US'}), 1.0]],
#  ['全自信度为:0.36348837209302326',
#   [frozenset({'California'}),
#    frozenset({'California', 'Central Coast', 'US'}),
#    1.0]],
#  ['全自信度为:0.19051235091794344',
#   [frozenset({'US'}),
#    frozenset({'Central Coast', 'Matt Kettmann', 'US'}),
#    1.0]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'Central Coast', 'Matt Kettmann', 'US'}),
#    0.909575602473875]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'Central Coast'}),
#    frozenset({'Central Coast', 'Matt Kettmann', 'US'}),
#    0.952221478008484]],
#  ['全自信度为:0.1475968992248062',
#   [frozenset({'California'}),
#    frozenset({'(85, 90]', '@mattkettmann', 'California'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'@mattkettmann', 'California', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:0.3472093023255814',
#   [frozenset({'California'}),
#    frozenset({'@mattkettmann', 'California', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'@mattkettmann', 'California', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:0.3306201550387597',
#   [frozenset({'California'}),
#    frozenset({'@mattkettmann', 'California', 'Central Coast'}),
#    1.0]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'@mattkettmann', 'California', 'Central Coast'}),
#    0.909575602473875]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'Central Coast'}),
#    frozenset({'@mattkettmann', 'California', 'Central Coast'}),
#    0.952221478008484]],
#  ['全自信度为:0.0850493590029928',
#   [frozenset({'US'}), frozenset({'(85, 90]', '@mattkettmann', 'US'}), 1.0]],
#  ['全自信度为:0.20007147004958234',
#   [frozenset({'US'}), frozenset({'@mattkettmann', 'California', 'US'}), 1.0]],
#  ['全自信度为:0.3472093023255814',
#   [frozenset({'California'}),
#    frozenset({'@mattkettmann', 'California', 'US'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'@mattkettmann', 'Matt Kettmann', 'US'}),
#    1.0]],
#  ['全自信度为:0.20007147004958234',
#   [frozenset({'US'}),
#    frozenset({'@mattkettmann', 'Matt Kettmann', 'US'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'@mattkettmann', 'Matt Kettmann', 'US'}),
#    1.0]],
#  ['全自信度为:0.19051235091794344',
#   [frozenset({'US'}),
#    frozenset({'@mattkettmann', 'Central Coast', 'US'}),
#    1.0]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'@mattkettmann', 'Central Coast', 'US'}),
#    0.909575602473875]],
#  ['全自信度为:0.909575602473875',
#   [frozenset({'Central Coast'}),
#    frozenset({'@mattkettmann', 'Central Coast', 'US'}),
#    0.952221478008484]],
#  ['全自信度为:0.42509488725161865',
#   [frozenset({'Matt Kettmann'}),
#    frozenset({'(85, 90]', '@mattkettmann', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:0.42509488725161865',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'(85, 90]', '@mattkettmann', 'Matt Kettmann'}),
#    1.0]],
#  ['全自信度为:0.3976334003125698',
#   [frozenset({'@mattkettmann'}),
#    frozenset({'(85, 90]', '@mattkettmann', 'Central Coast'}),
#    0.86962890625]],
#  ['全自信度为:0.3798251226274259',
#   [frozenset({'Central Coast'}),
#    frozenset({'(85, 90]', '@mattkettmann', 'Central Coast'}),
#    0.9353991596638656]],
#  ['全自信度为:0.16000357350247912',
#   [frozenset({'US'}), frozenset({'(20, 30]', '(85, 90]', 'US'}), 1.0]],
#  ['全自信度为:0.12413454236833876',
#   [frozenset({'US'}), frozenset({'(20, 30]', 'California', 'US'}), 1.0]],
#  ['全自信度为:0.17533478667081906',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'California', 'Napa Valley', 'Virginie Boone'}),
#    0.9765828274067649]],
#  ['全自信度为:0.08728682170542636',
#   [frozenset({'California'}),
#    frozenset({'California', 'Napa Valley', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.08813953488372092',
#   [frozenset({'California'}),
#    frozenset({'Cabernet Sauvignon', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17533478667081906',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'Napa Valley', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17533478667081906',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Napa Valley', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.49782945736434103',
#   [frozenset({'California'}),
#    frozenset({'@vboone', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17704764870756773',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'Cabernet Sauvignon', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17704764870756773',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Cabernet Sauvignon', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.14794300263545807',
#   [frozenset({'US'}), frozenset({'(85, 90]', 'US', 'Virginie Boone'}), 1.0]],
#  ['全自信度为:0.2567441860465116',
#   [frozenset({'California'}),
#    frozenset({'(85, 90]', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.5157271877919651',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'(85, 90]', '@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.5157271877919651',
#   [frozenset({'@vboone'}),
#    frozenset({'(85, 90]', '@vboone', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.5829015544041452',
#   [frozenset({'Napa'}),
# ...
#   [frozenset({'US'}),
#    frozenset({'@vboone', 'California', 'Napa Valley', 'US'}),
#    1.0]],
#  ['全自信度为:0.17533478667081906',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'California', 'Napa Valley', 'US'}),
#    0.9765828274067649]],
#  ['全自信度为:0.08728682170542636',
#   [frozenset({'California'}),
#    frozenset({'@vboone', 'California', 'Napa Valley', 'US'}),
#    1.0]],
#  ['全自信度为:0.28686291151114485',
#   [frozenset({'US'}),
#    frozenset({'@vboone', 'California', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'California', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:1.0',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'California', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.49782945736434103',
#   [frozenset({'California'}),
#    frozenset({'@vboone', 'California', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.05078840398445526',
#   [frozenset({'US'}),
#    frozenset({'Cabernet Sauvignon', 'California', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.08813953488372092',
#   [frozenset({'California'}),
#    frozenset({'Cabernet Sauvignon', 'California', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.05029704739357663',
#   [frozenset({'US'}),
#    frozenset({'California', 'Napa Valley', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17533478667081906',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'California', 'Napa Valley', 'US', 'Virginie Boone'}),
#    0.9765828274067649]],
#  ['全自信度为:0.08728682170542636',
#   [frozenset({'California'}),
#    frozenset({'California', 'Napa Valley', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.14794300263545807',
#   [frozenset({'US'}),
#    frozenset({'(85, 90]', '@vboone', 'California', 'US'}),
#    1.0]],
#  ['全自信度为:0.2567441860465116',
#   [frozenset({'California'}),
#    frozenset({'(85, 90]', '@vboone', 'California', 'US'}),
#    1.0]],
#  ['全自信度为:0.14794300263545807',
#   [frozenset({'US'}),
#    frozenset({'(85, 90]', 'California', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.2567441860465116',
#   [frozenset({'California'}),
#    frozenset({'(85, 90]', 'California', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.08469200875508108',
#   [frozenset({'US'}),
#    frozenset({'@vboone', 'California', 'Napa', 'US'}),
#    1.0]],
#  ['全自信度为:0.2952351292432264',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'California', 'Napa', 'US'}),
#    0.9823834196891194]],
#  ['全自信度为:0.14697674418604653',
#   [frozenset({'California'}),
#    frozenset({'@vboone', 'California', 'Napa', 'US'}),
#    1.0]],
#  ['全自信度为:0.5829015544041452',
#   [frozenset({'Napa'}),
#    frozenset({'@vboone', 'Napa', 'Napa Valley', 'US'}),
#    0.9991119005328597]],
#  ['全自信度为:0.05025237861258766',
#   [frozenset({'US'}),
#    frozenset({'@vboone', 'Napa', 'Napa Valley', 'US'}),
#    1.0]],
#  ['全自信度为:0.17517907194020554',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Napa', 'Napa Valley', 'US'}),
#    0.9765624999999999]],
#  ['全自信度为:0.5968911917098446',
#   [frozenset({'Napa'}),
#    frozenset({'California', 'Napa', 'Napa Valley', 'US'}),
#    0.9991326973113617]],
#  ['全自信度为:0.05145843569928977',
#   [frozenset({'US'}),
#    frozenset({'California', 'Napa', 'Napa Valley', 'US'}),
#    1.0]],
#  ['全自信度为:0.08930232558139535',
#   [frozenset({'California'}),
#    frozenset({'California', 'Napa', 'Napa Valley', 'US'}),
#    1.0]],
#  ['全自信度为:0.08469200875508108',
#   [frozenset({'US'}),
#    frozenset({'@vboone', 'Napa', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.2952351292432264',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Napa', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.2952351292432264',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'Napa', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.08469200875508108',
#   [frozenset({'US'}),
#    frozenset({'California', 'Napa', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.14697674418604653',
#   [frozenset({'California'}),
#    frozenset({'California', 'Napa', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.2952351292432264',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'California', 'Napa', 'US', 'Virginie Boone'}),
#    0.9823834196891194]],
#  ['全自信度为:0.5829015544041452',
#   [frozenset({'Napa'}),
#    frozenset({'Napa', 'Napa Valley', 'US', 'Virginie Boone'}),
#    0.9991119005328597]],
#  ['全自信度为:0.05025237861258766',
#   [frozenset({'US'}),
#    frozenset({'Napa', 'Napa Valley', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17517907194020554',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'Napa', 'Napa Valley', 'US', 'Virginie Boone'}),
#    0.9765624999999999]],
#  ['全自信度为:0.5829015544041452',
#   [frozenset({'Napa'}),
#    frozenset({'@vboone', 'California', 'Napa', 'Napa Valley'}),
#    0.9991119005328597]],
#  ['全自信度为:0.17517907194020554',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'California', 'Napa', 'Napa Valley'}),
#    0.9765624999999999]],
#  ['全自信度为:0.0872093023255814',
#   [frozenset({'California'}),
#    frozenset({'@vboone', 'California', 'Napa', 'Napa Valley'}),
#    1.0]],
#  ['全自信度为:0.2952351292432264',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'California', 'Napa', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.2952351292432264',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'California', 'Napa', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.14697674418604653',
#   [frozenset({'California'}),
#    frozenset({'@vboone', 'California', 'Napa', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.5829015544041452',
#   [frozenset({'Napa'}),
#    frozenset({'California', 'Napa', 'Napa Valley', 'Virginie Boone'}),
#    0.9991119005328597]],
#  ['全自信度为:0.17517907194020554',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'California', 'Napa', 'Napa Valley', 'Virginie Boone'}),
#    0.9765624999999999]],
#  ['全自信度为:0.0872093023255814',
#   [frozenset({'California'}),
#    frozenset({'California', 'Napa', 'Napa Valley', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.05029704739357663',
#   [frozenset({'US'}),
#    frozenset({'@vboone', 'Napa Valley', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17533478667081906',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Napa Valley', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17533478667081906',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'Napa Valley', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.5829015544041452',
#   [frozenset({'Napa'}),
#    frozenset({'@vboone', 'Napa', 'Napa Valley', 'Virginie Boone'}),
#    0.9991119005328597]],
#  ['全自信度为:0.17517907194020554',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'Napa', 'Napa Valley', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17517907194020554',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'Napa', 'Napa Valley', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.14794300263545807',
#   [frozenset({'US'}),
#    frozenset({'(85, 90]', '@vboone', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.5157271877919651',
#   [frozenset({'@vboone'}),
#    frozenset({'(85, 90]', '@vboone', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.5157271877919651',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'(85, 90]', '@vboone', 'US', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.2567441860465116',
#   [frozenset({'California'}),
#    frozenset({'(85, 90]', '@vboone', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.5157271877919651',
#   [frozenset({'@vboone'}),
#    frozenset({'(85, 90]', '@vboone', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.5157271877919651',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'(85, 90]', '@vboone', 'California', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.08813953488372092',
#   [frozenset({'California'}),
#    frozenset({'@vboone',
#               'Cabernet Sauvignon',
#               'California',
#               'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17704764870756773',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone',
#               'Cabernet Sauvignon',
#               'California',
#               'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17704764870756773',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone',
#               'Cabernet Sauvignon',
#               'California',
#               'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.08728682170542636',
#   [frozenset({'California'}),
#    frozenset({'@vboone', 'California', 'Napa Valley', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17533478667081906',
#   [frozenset({'@vboone'}),
#    frozenset({'@vboone', 'California', 'Napa Valley', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.17533478667081906',
#   [frozenset({'Virginie Boone'}),
#    frozenset({'@vboone', 'California', 'Napa Valley', 'Virginie Boone'}),
#    1.0]],
#  ['全自信度为:0.2938720988478878',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.2938720988478878',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon', 'Paul Gregutt'}),
#    1.0]],
#  ['全自信度为:0.33177492068792785',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'Pinot Noir'}),
#    1.0]],
#  ['全自信度为:0.33177492068792785',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'Pinot Noir'}),
#    1.0]],
#  ['全自信度为:0.5695041559186013',
#   [frozenset({'Oregon'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'Pinot Noir'}),
#    0.9989944695827049]],
#  ['全自信度为:0.2938720988478878',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon', 'US'}),
#    0.9436997319034852]],
#  ['全自信度为:0.07861705454058159',
#   [frozenset({'US'}),
#    frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon', 'US'}),
#    1.0]],
#  ['全自信度为:0.5530138587410252',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'US'}),
#    1.0]],
#  ['全自信度为:0.14794300263545807',
#   [frozenset({'US'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'US'}),
#    1.0]],
#  ['全自信度为:0.5530138587410252',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'Paul Gregutt', 'US'}),
#    1.0]],
#  ['全自信度为:0.33177492068792785',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'Pinot Noir', 'US'}),
#    0.9721135029354208]],
#  ['全自信度为:0.08875686782507705',
#   [frozenset({'US'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'Pinot Noir', 'US'}),
#    1.0]],
#  ['全自信度为:0.5695041559186013',
#   [frozenset({'Oregon'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'Pinot Noir', 'US'}),
#    0.9989944695827049]],
#  ['全自信度为:0.22057104691935217',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon', 'Willamette Valley'}),
#    0.9828869047619048]],
#  ['全自信度为:0.37861851533390656',
#   [frozenset({'Oregon'}),
#    frozenset({'(85, 90]', '@paulgwine\xa0', 'Oregon', 'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.4287861078644181',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0',
#               'Oregon',
#               'Paul Gregutt',
#               'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.4287861078644181',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'@paulgwine\xa0',
#               'Oregon',
#               'Paul Gregutt',
#               'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.7360275150472915',
#   [frozenset({'Oregon'}),
#    frozenset({'@paulgwine\xa0',
#               'Oregon',
#               'Paul Gregutt',
#               'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.3087326765737185',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'Pinot Noir', 'Willamette Valley'}),
#    0.9824654622741765]],
#  ['全自信度为:0.7103342297349212',
#   [frozenset({'Willamette Valley'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'Pinot Noir', 'Willamette Valley'}),
#    0.9305485656768999]],
#  ['全自信度为:0.529951275437088',
#   [frozenset({'Oregon'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'Pinot Noir', 'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.4287861078644181',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'US', 'Willamette Valley'}),
#    0.9865539761813292]],
#  ['全自信度为:0.11470942957966677',
#   [frozenset({'US'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'US', 'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.7360275150472915',
#   [frozenset({'Oregon'}),
#    frozenset({'@paulgwine\xa0', 'Oregon', 'US', 'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.5376523626648857',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'(85, 90]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#    1.0]],
#  ['全自信度为:0.14383347478447314',
#   [frozenset({'US'}),
#    frozenset({'(85, 90]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#    1.0]],
#  ['全自信度为:0.5376523626648857',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'(85, 90]', '@paulgwine\xa0', 'Paul Gregutt', 'US'}),
#    1.0]],
#  ['全自信度为:0.22057104691935217',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'(85, 90]',
#               '@paulgwine\xa0',
#               'Paul Gregutt',
#               'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.22057104691935217',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'(85, 90]',
#               '@paulgwine\xa0',
#               'Paul Gregutt',
#               'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.07861705454058159',
#   [frozenset({'US'}),
#    frozenset({'(85, 90]', 'Oregon', 'Paul Gregutt', 'US'}),
#    1.0]],
#  ['全自信度为:0.2938720988478878',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'(85, 90]', 'Oregon', 'Paul Gregutt', 'US'}),
#    0.9436997319034852]],
#  ['全自信度为:0.33210886625480046',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Pinot Noir', 'US'}),
#    1.0]],
#  ['全自信度为:0.08884620538705498',
#   [frozenset({'US'}),
#    frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Pinot Noir', 'US'}),
#    1.0]],
#  ['全自信度为:0.33210886625480046',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'Pinot Noir', 'US'}),
#    1.0]],
#  ['全自信度为:0.3087326765737185',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0',
#               'Paul Gregutt',
#               'Pinot Noir',
#               'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.3087326765737185',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'@paulgwine\xa0',
#               'Paul Gregutt',
#               'Pinot Noir',
#               'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.7103342297349212',
#   [frozenset({'Willamette Valley'}),
#    frozenset({'@paulgwine\xa0',
#               'Paul Gregutt',
#               'Pinot Noir',
#               'Willamette Valley'}),
#    0.9296128707893415]],
#  ['全自信度为:0.08875686782507705',
#   [frozenset({'US'}),
#    frozenset({'Oregon', 'Paul Gregutt', 'Pinot Noir', 'US'}),
#    1.0]],
#  ['全自信度为:0.33177492068792785',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'Oregon', 'Paul Gregutt', 'Pinot Noir', 'US'}),
#    0.9721135029354208]],
#  ['全自信度为:0.5695041559186013',
#   [frozenset({'Oregon'}),
#    frozenset({'Oregon', 'Paul Gregutt', 'Pinot Noir', 'US'}),
#    0.9989944695827049]],
#  ['全自信度为:0.22057104691935217',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'(85, 90]', '@paulgwine\xa0', 'US', 'Willamette Valley'}),
#    0.9828869047619048]],
#  ['全自信度为:0.05900745968642516',
#   [frozenset({'US'}),
#    frozenset({'(85, 90]', '@paulgwine\xa0', 'US', 'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.4287861078644181',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'US', 'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.11470942957966677',
#   [frozenset({'US'}),
#    frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'US', 'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.4287861078644181',
#   [frozenset({'Paul Gregutt'}),
#    frozenset({'@paulgwine\xa0', 'Paul Gregutt', 'US', 'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.3087326765737185',
#   [frozenset({'@paulgwine\xa0'}),
#    frozenset({'@paulgwine\xa0', 'Pinot Noir', 'US', 'Willamette Valley'}),
#    0.9824654622741765]],
#  ['全自信度为:0.08259257604859964',
#   [frozenset({'US'}),
#    frozenset({'@paulgwine\xa0', 'Pinot Noir', 'US', 'Willamette Valley'}),
#    1.0]],
#  ['全自信度为:0.7103342297349212',
#   [frozenset({'Willamette Valley'}),
#    frozenset({'@paulgwine\xa0', 'Pinot Noir', 'US', 'Willamette Valley'}),
#    0.9296128707893415]],
#  ['全自信度为:0.37861851533390656',
#   [frozenset({'Oregon'}),
#    frozenset({'(85, 90]', 'Oregon', 'Paul Gregutt', 'Willamette Valley'}),
#    1.0]],
#  ...]
